# %%
#!/usr/bin/env python 3
import re
import csv

#PATH = "./"
PATH = "/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/"
CHAIN_FILE = "combined/comboChains.csv"
#CHAIN_FILE = "tempChains.csv"
PDB_LIST = "combined/comboID.txt"
#PDB_LIST = "tempID.txt"

# %%
#PARAMETERS:
#fils is a string with path to the file to be checked

#RESULTS:
#Returns 1 or 0 depending on file existence 


def file_check(file):
    
    try:
        open(file, "r")
        return 1
    
    except IOError:
        print("Error: " + file + " does not appear to exist.")
        return 0

# %%
#PARAMETERS:
#name is a string with the name of chain
#typeCount is a 2-element list with the first one being an empty string and the second - 0 (iteger)

#RESULTS:
#Updates the typeCount array: the first element = general histone type(s); the second element = (should be) number of histones in chain

def is_histone(name, typeCount):

    if(re.search(r'histone', name, re.I)):
       
        if(not re.search(r'chaperone|ase|ing|hsh49|rep|alpha|thioredoxin|bombinin|chromosomal|nucleoprotein|envelope|snrnp', name, re.I)):
            
            typeCount[1] = 1 #adds the number of histones in chain  (should be changed to actual number of histones in chain!!!)

            if(re.search(r'h2a', name, re.I)):
                typeCount[0] += 'H2A|'
                
            elif(re.search(r'h2b', name, re.I)):
                typeCount[0] += 'H2B|'
                    
            elif(re.search(r'h3', name, re.I)):
                typeCount[0] += 'H3|'
                    
            elif(re.search(r'h4', name, re.I)):
                typeCount[0] += 'H4|'
                    
            elif(re.search(r'h1', name, re.I)):
                typeCount[0] += 'H1|'  
                    
            elif(re.search(r'h5', name, re.I)):
                typeCount[0] += 'H5|'

            elif(re.search(r'arch', name, re.I)):
                typeCount[0] += 'archaeal histone|'
                
            else:
                typeCount[0] += 'some histone|'

# %%
#PARAMETERS:
#name is a string with the name of chain
#typeCount is a 2-element list with the first one being an empty string and the second - 0 (iteger)

#RESULTS:
#Updates the typeCount array: the first element = general histone type(s); the second element = (should be) number of histones in chain

def is_histone2(name, typeCount):

    if(re.search(r'histone|h3|h4|h2a|lys\(ac\)', name, re.I)):
       
        if(not re.search(r'chaperone|ase|ing|fasciclin|rna|chain|region|fold|llama|anti|inhibitor|nanobody|nucleoprotein|regulatory|insulin|nr1h|upf0052|hiv|affitin|envelope|ddef|bh3|hsh49|1h4i|h2afy|h2a1', name, re.I)):
            
            typeCount[1] = 1 #adds the number of histones in chain  (should be changed to actual number of histones in chain!!!)

            if(re.search(r'h2a', name, re.I)):
                typeCount[0] += 'H2A|'
                
            elif(re.search(r'h2b', name, re.I)):
                typeCount[0] += 'H2B|'
                    
            elif(re.search(r'h4', name, re.I)):
                typeCount[0] += 'H4|'
                    
            elif(re.search(r'h1', name, re.I)):
                typeCount[0] += 'H1|'  
                    
            elif(re.search(r'h5', name, re.I)):
                typeCount[0] += 'H5|'

            elif(re.search(r'arch', name, re.I)):
                typeCount[0] += 'archaeal histone|'
                
            elif(re.search(r'h3|histone 3|', name, re.I)):
                typeCount[0] += 'H3|'  
                
            else:
                typeCount[0] += 'some histone|'

# %%
#PARAMETERS: 
#pdbList is a text file with a header and one column PDB
#files is a list
#parameter is a string, either 'mapping' or 'interface' depending on desired results

#RESULTS:
#A list of absolute paths to either mapping files or interface files as it is stored on local NCBI machines


def get_files(pdbList, files, parameter):
    
    with open(pdbList, 'r') as pfh:
        
        if(parameter == 'mapping'):
            
            for line in pfh:
                line = line.strip()
                folder = line[1] + line[2] 
                files.append(PATH + folder + '/' + line + '_chain_protein_mapping.tab')
                
        elif(parameter == 'interface'): 
            
            for line in pfh:
                line = line.strip()
                folder = line[1] + line[2]
                files.append(PATH + folder + '/' + line + '_atomic_contacts_5.0A.tab')

# %%
#PARAMETERS: 
#pdb is a string with pdb id
#parameter is a string, either 'mapping' or 'interface' depending on desired results

#RESULTS:
#An absolute paths to either mapping file or interface file as it is stored on local NCBI machines


def get_file(pdb, parameter):
    
    if(parameter == 'mapping'):
        folder = pdb[1] + pdb[2] 
        file = (PATH + folder + '/' + pdb + '_chain_protein_mapping.tab')
        return file  
        
    elif(parameter == 'interface'): 
        folder = pdb[1] + pdb[2]
        file = (PATH + folder + '/' + pdb + '_atomic_contacts_5.0A.tab')
        return file

# %%
#PARAMETERS:
#cFile is tab-separated file with a header and 4 columns: pdb, chain, uniprot, name
#dictionary is nested with the innermost dict being dictionary['pdb'] = {}

#RESULTS: 
#Example: {1alq : {'G': 'A|p84233|Histone H3.2|H3|Xenopus laevis|nucleosome:1|bp:1|1|1|135'}}

def get_chain_dictionaries(cFile, dictionary): 
    
    #with open(cFile, 'r') as cfh:
        #cfh.readline()

    histoneCount = {} #is used to count number of histones in a structure!!!!!!!

    tempDict = {}
    tempDict['pdb'] = {}

    tempDict2 = {}
    tempDict2['pdb'] = {}
    
    mappingFiles = [] 
    get_files(PDB_LIST, mappingFiles, 'mapping')


    for file in mappingFiles:

        try: #adds a pdb entry to the dict only if mapping file exists

            with open(file, 'r') as mfh:
                mfh.readline() #skips header
                pdb = file.split('/')[-1].split('_', 1)[0]

                for mLine in mfh:
                    chainPair = mLine.split('\t')
                    alexChain = chainPair[0]
                    myChain = chainPair[1]
                    alignment = int(chainPair[7]) - int(chainPair[3])
                    mmCIFstart = int(chainPair[3])
                    mmCIFend = int(chainPair[5])
                    
                    if(pdb in tempDict):
                        if(alexChain in tempDict[pdb]):
                            tempDict2[pdb][alexChain].extend([alignment, mmCIFstart, mmCIFend])
                        else:
                            tempDict[pdb][alexChain] = myChain
                            tempDict2[pdb][alexChain] = [alignment, mmCIFstart, mmCIFend]
                        
                    else:
                        tempDict[pdb] = {alexChain : myChain}
                        tempDict2[pdb] = {alexChain : [alignment, mmCIFstart, mmCIFend]}

        except IOError:
            pass
            #print("Error: " + mappingFile + " does not appear to exist.")


    chains_file = csv.DictReader(open(cFile)) 

    for cLine in chains_file:

        pdb = cLine["structureId"].lower()
        if(pdb in tempDict): #continues only if a mapping file exists
            chain = cLine["chainId"]
            organism = cLine["source"]
            uniprot = cLine["uniprotAcc"].lower()
            name = cLine["uniprotRecommendedName"]

            histoneTypeAndCount = ['', 0]

            if(name):
                is_histone(name, histoneTypeAndCount) #checks whether the name looks like a histone!!!!!!!!!

            else:
                name = cLine["compound"]
                is_histone2(name, histoneTypeAndCount)

            tempType = histoneTypeAndCount[0]
            tempCount = histoneTypeAndCount[1]

            #######################
            if(tempCount): #if the chain is a [part of a] histone

                if(pdb in histoneCount):

                    if(tempType not in histoneCount[pdb]):
                        histoneCount[pdb].append(tempType) #!!!!!!

                else:
                    histoneCount[pdb] = [tempType]       

            try: #adds a chain entry to the dict only if there exists a corresponding chain in the mapping file
                alexChain = list(tempDict[pdb].keys())[list(tempDict[pdb].values()).index(chain)]

                if(pdb in dictionary):

                    if(tempCount): #checks if chain is a histone!!!!
                        dictionary[pdb][alexChain] = str(tempDict[pdb][alexChain]) + '|' + uniprot + '|' + name + '|' + tempType + organism + '|' #!!!!

                    else: #!!!!
                        dictionary[pdb][alexChain] = str(tempDict[pdb][alexChain]) + '|' + uniprot + '|' + name + '|' + 'other|' + organism  + '|' #!!!!

                else:

                    if(tempCount): #checks if chain is a histone!!!!
                        dictionary[pdb] = {alexChain : str(tempDict[pdb][alexChain]) + '|' + uniprot + '|' + name + '|' + tempType + organism + '|'} #!!!!

                    else: #!!!!
                        dictionary[pdb] = {alexChain : str(tempDict[pdb][alexChain]) + '|' + uniprot + '|' + name + '|' + 'other|' + organism + '|'} #!!!!

            except ValueError:
                #print("Error: " + str(ValueError) + ", in " + pdb)               
                pass


    with open('combined/temp.tsv', 'w') as rfh:
        for structure in list(dictionary): 

            if(structure in histoneCount):
                uniqueHistoneNum = len(histoneCount[structure])
                partnerFlag = 0

                if(uniqueHistoneNum > 2): #checks if pdb has at least 3 different histones ~ is a nucleosome!!!!!!!

                    for chain in dictionary[structure]:
                        chainFields = dictionary[structure][chain].split('|')

                        chainType = chainFields[3]  ##

                        dictionary[structure][chain] += 'nucleosome:1|' #!!!!!!

                        if(partnerFlag == 0 and chainType == 'other'):
                            partnerFlag = 1

                    if(partnerFlag == 0):
                        for chain in dictionary[structure]:
                            dictionary[structure][chain] += 'bp:0|'
                            for element in tempDict2[structure][chain]:
                                dictionary[structure][chain] += str(element)
                                dictionary[structure][chain] += '|'
                            dictionary[structure][chain] += str(len(tempDict2[structure][chain]) / 3)
                            rfh.write(str(dictionary[structure][chain]) + '\n')
                            
                            #rfh.write(structure + '\t' + 'nucleosome' + '\t' + 'no' + '\n')
                    else:
                        for chain in dictionary[structure]:
                            dictionary[structure][chain] += 'bp:1|'
                            for element in tempDict2[structure][chain]:
                                dictionary[structure][chain] += str(element)
                                dictionary[structure][chain] += '|'
                            dictionary[structure][chain] += str(len(tempDict2[structure][chain]) / 3)
                            rfh.write(str(dictionary[structure][chain]) + '\n')
                            #rfh.write(structure + '\t' + 'nucleosome' + '\t' + 'yes' + '\n')
                else: #!!!!!!

                    for chain in dictionary[structure]: #!!!!!
                        chainFields = dictionary[structure][chain].split('|')

                        chainType = chainFields[3]

                        dictionary[structure][chain] += 'nucleosome:0|' #!!!!!! 

                        if(partnerFlag == 0 and chainType == 'other'):
                            partnerFlag = 1

                    if(partnerFlag == 0):
                        for chain in dictionary[structure]:
                            dictionary[structure][chain] += 'bp:0|'
                            for element in tempDict2[structure][chain]:
                                dictionary[structure][chain] += str(element)
                                dictionary[structure][chain] += '|'
                            dictionary[structure][chain] += str(len(tempDict2[structure][chain]) / 3)
                            rfh.write(str(dictionary[structure][chain]) + '\n')
                            #rfh.write(structure + '\t' + 'histone' + '\t' + 'no' + '\n')
                    else:
                        for chain in dictionary[structure]:
                            dictionary[structure][chain] += 'bp:1|'
                            for element in tempDict2[structure][chain]:
                                dictionary[structure][chain] += str(element)
                                dictionary[structure][chain] += '|'
                            dictionary[structure][chain] += str(len(tempDict2[structure][chain]) / 3)
                            rfh.write(str(dictionary[structure][chain]) + '\n')
                            #rfh.write(structure + '\t' + 'histone' + '\t' + 'yes' + '\n')
            else:
                for chain in dictionary[structure]:
                    chainFields = dictionary[structure][chain].split('|')

                    chainType = chainFields[3]  ##

                    dictionary[structure][chain] += 'other:0|' #!!!!!!
                            
                    #rfh.write(structure + '\t' + 'nucleosome' + '\t' + 'no' + '\n')

                for chain in dictionary[structure]:
                    dictionary[structure][chain] += 'bp:1|'
                    for element in tempDict2[structure][chain]:
                        dictionary[structure][chain] += str(element)
                        dictionary[structure][chain] += '|'
                    dictionary[structure][chain] += str(len(tempDict2[structure][chain]) / 3)
                    rfh.write(str(dictionary[structure][chain]) + '\n')
                #del dictionary[structure]

# %%
#PARAMETERS:
#interfaceFiles is a list of strings containing names of interface files
#chainDictionary is a dictionary produced by 'get_chain_dictionaries'
#interfaceDictonary is a nested dictionary with the innermost dict being interfaceDictionary['uniprotPair'] = {}, where the values are lists of the next form [chain pair data, residue number, pdb IDs] 
#Example: 'P84233@P62799': {'44': ['A|P84233|Histone H3.2|h3|1@B|P62799|Histone H4|h4|1$E|P84233|Histone H3.2|h3|1@F|P62799|Histone H4|h4|1', 17, '1zla$q5cl']
#note that data fields of a chain is separated by |, @ separates chain from binding partner chain, $ separates chain pairs and pdb structures
#A|P84233|Histone H3.2|H3|Xenopus laevis|nucleosome:1|bp:1


def residue_count(interfaceFiles, chainDictionary, interfaceDictionary):
    
    for file in interfaceFiles:
        pdb = file.split('/')[-1].split('_', 1)[0] 

        try:
            
            with open (file, 'r') as ifh:
                ifh.readline()

                with open('combined/results.tsv', 'a') as rfh:
                                     
                    for line in ifh:
                        lineFields = line.split('\t')

                        chain1 = lineFields[0].split('_', 1)[0] # the split part treats biological assembly chains as separate chains ???
                        chain2 = lineFields[4].split('_', 1)[0]

                        fields1 = chainDictionary[pdb][chain1].split('|')
                        fields2 = chainDictionary[pdb][chain2].split('|')

                        myChain1 = fields1[0]
                        myChain2 = fields2[0]
                        
                        type1 = fields1[3]
                        type2 = fields2[3]
                        
                        #nucleosome = int(fields1[5].split(':')[1])
                        bp = int(fields1[6].split(':')[1])
                        
                        align1 = int(fields1[7])
                        align2 = int(fields2[7])
                        
                        mmCIFstart1 = int(fields1[8])
                        mmCIFstart2 = int(fields2[8])
                        
                        mmCIFend1 = int(fields1[9])
                        mmCIFend2 = int(fields2[9])
                        
                        uniprotStart1 = mmCIFstart1 + align1
                        uniprotStart2 = mmCIFstart2 + align2
                        
                        uniprotEnd1 = mmCIFend1 + align1
                        uniprotEnd2 = mmCIFend2 + align2
                        
                        #if(not nucleosome and bp and type1 != 'other' and type2 == 'other'):
                        if(type1 != 'other' and type2 == 'other'):
                            
                            residue1 = lineFields[2]
                            residue2 = lineFields[6]
                            if((type1 == 'H1' and 1 <= uniprotStart1 <= 229 and 1 <= uniprotEnd1 <= 229) or (type1 == 'H2A' and 1 <= uniprotStart1 <= 385 and 1 <= uniprotEnd1 <= 385) or (type1 == 'H2B' and 1 <= uniprotStart1 <= 133 and 1 <= uniprotEnd1 <= 133) or (type1 == 'H3' and 1 <= uniprotStart1 <= 184 and 1 <= uniprotEnd1 <= 184) or (type1 == 'H4' and 1 <= uniprotStart1 <= 103 and 1 <= uniprotEnd1 <= 103)):
                                if(int(residue1) >= mmCIFstart1 and int(residue1) <= mmCIFend1):

                                    with open('combined/hitdata.txt', 'r') as hfh:
                                        hfh.readline()
                                        domainFlag = 0
                                        
                                        for line in hfh:
                                            fields = line.split('\t')


                                            pdb2 = fields[0].split(' - ')[1][0:4].lower() ###
                                            chain = fields[0].split(' - ')[1][4]  ###


                                            start = int(fields[3])
                                            end = int(fields[4])
                                            domtype = fields[1]
                                            name = fields[8]

                                            if(pdb2 == pdb and chain == myChain2):

                                                if(domtype == 'specific'):
                                                    if(int(residue2) >= int(start) and int(residue2) <= int(end)):
                                                        hfields = chainDictionary[pdb][chain1].split('|')
                                                        pfields = chainDictionary[pdb][chain2].split('|')
                                                        alignedRes = int(residue1) + align1
                                                        domainFlag = 1
                                                        rfh.write(hfields[1] +'\t' + hfields[2] + '\t' + hfields[4] + '\t' + hfields[3] + '_' + str(alignedRes) + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + name + '\t' + pfields[4] + '\t' + hfields[3] + '\t' + str(alignedRes) + '\t' + pdb + '\n')
                                                        #print(hfields[2] + '\t' + hfields[3] + '\t' + hfields[4] + '\t' + residue1 + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + pfields[4] + '\t' + name)
                                        hfh.seek(0)
                                        if(not domainFlag):
                                            hfields = chainDictionary[pdb][chain1].split('|')
                                            pfields = chainDictionary[pdb][chain2].split('|')
                                            alignedRes = int(residue1) + align1
                                            rfh.write(hfields[1] +'\t' + hfields[2] + '\t' + hfields[4] + '\t' + hfields[3] + '_' + str(alignedRes) + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + 'NA' + '\t' + pfields[4] + '\t' + hfields[3] + '\t' + str(alignedRes) + '\t' + pdb + '\n')
                                #else:
                                    #print(pdb, type1, residue1, mmCIFstart1, mmCIFend1)
                            #else:
                                #print(pdb + '\t' + fields1[0] + '\t' + fields1[2] + '\t' + str(uniprotStart1) + '\t' + str(uniprotEnd1) + '\n')

                        #if(not nucleosome and bp and type2 != 'other' and type1 == 'other'):
                        elif(type2 != 'other' and type1 == 'other'):

                            residue1 = lineFields[2]
                            residue2 = lineFields[6]
                            if((type2 == 'H1' and 1 <= uniprotStart2 <= 229 and 1 <= uniprotEnd2 <= 229) or (type2 == 'H2A' and 1 <= uniprotStart2 <= 385 and 1 <= uniprotEnd2 <= 385) or (type2 == 'H2B' and 1 <= uniprotStart2 <= 133 and 1 <= uniprotEnd2 <= 133) or (type2 == 'H3' and 1 <= uniprotStart2 <= 184 and 1 <= uniprotEnd2 <= 184) or (type2 == 'H4' and 1 <= uniprotStart2 <= 103 and 1 <= uniprotEnd2 <= 103)):
                                if(int(residue2) >= mmCIFstart2 and int(residue2) <= mmCIFend2):

                                    with open('combined/hitdata.txt', 'r') as hfh:
                                        hfh.readline()
                                        domainFlag = 0
                                        for line in hfh:
                                            fields = line.split('\t')


                                            pdb2 = fields[0].split(' - ')[1][0:4].lower() ###
                                            chain = fields[0].split(' - ')[1][4]  ###

                                            start = int(fields[3])
                                            end = int(fields[4])
                                            domtype = fields[1]
                                            name = fields[8]
                                            if(pdb2 == pdb and chain == myChain1):

                                                if(domtype == 'specific'):
                                                    if(int(residue1) >= int(start) and int(residue1) <= int(end)):
                                                        hfields = chainDictionary[pdb][chain2].split('|')
                                                        pfields = chainDictionary[pdb][chain1].split('|')
                                                        alignedRes = int(residue2) + align2
                                                        rfh.write(hfields[1] +'\t' + hfields[2] + '\t' + hfields[4] + '\t' + hfields[3] + '_' + str(alignedRes) + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + name + '\t' + pfields[4] + '\t' + hfields[3] + '\t' + str(alignedRes) + '\t' + pdb + '\n')
                                                        domaingFlag = 1
                                                        #print(hfields[2] + '\t' + hfields[3] + '\t' + hfields[4] + '\t' + residue2 + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + pfields[4] + '\t' + name)
                                        hfh.seek(0)
                                        if(not domainFlag):
                                            hfields = chainDictionary[pdb][chain2].split('|')
                                            alignedRes = int(residue2) + align2
                                            pfields = chainDictionary[pdb][chain1].split('|')
                                            rfh.write(hfields[1] +'\t' + hfields[2] + '\t' + hfields[4] + '\t' + hfields[3] + '_' + str(alignedRes) + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + 'NA' + '\t' + pfields[4] + '\t' + hfields[3] + '\t' + str(alignedRes) + '\t' + pdb + '\n')
                                #else:
                                    #print(pdb, type2, residue2, mmCIFstart2, mmCIFend2)
                            #else:
                                #print(pdb + '\t' + fields2[0] + '\t' + fields2[2] + '\t' + str(uniprotStart2) + '\t' + str(uniprotEnd2) + '\n')
                                
                        elif(type2 == 'other' and type1 == 'other'):

                            hfields = chainDictionary[pdb][chain2].split('|')
                            pfields = chainDictionary[pdb][chain1].split('|')

                            rfh.write(hfields[1] +'\t' + hfields[2] + '\t' + hfields[4] + '\t' + hfields[3] + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + '' + '\t' + pfields[4] + '\t' + hfields[3] + '\t' + '' + '\t' + pdb + '\n')
                            #print(hfields[2] + '\t' + hfields[3] + '\t' + hfields[4] + '\t' + residue2 + '\t' + pfields[1] + '\t' + pfields[2] + '\t' + pfields[4] + '\t' + name)
                        

        except (IOError, KeyError) as e:
            #print("Error: " + file + " does not appear to exist.")
            print(e)
            pass

# %%
def main():
    chainDictionary = {}
    chainDictionary['chain'] = {}
    get_chain_dictionaries(CHAIN_FILE, chainDictionary)
    #for pdb in chainDictionary:
     #   for chain in chainDictionary[pdb]:
      #      print(pdb + '\t' + chain + '\t' + str(chainDictionary[pdb][chain]))

    interfaceFiles = []
    get_files(PDB_LIST, interfaceFiles, 'interface')

    interfaceDictionary = {}
    interfaceDictionary['uniprotPair'] = {}
    residue_count(interfaceFiles, chainDictionary, interfaceDictionary)
#     for pair in interfaceDictionary:
#         for a in interfaceDictionary[pair]:
#             print(pair + '\t' + a + '\t' + str(interfaceDictionary[pair][a]))

# %%
if __name__ == "__main__":
    main()
# Out:
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/47/147l_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/m3/1m36_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bd/2bd9_atomic_contacts_5.0A.tab'
# '3r6k'
# '6fqs'
# '5t4b'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b0/3b0w_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/gt/5gtf_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/id/4idr_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nx/5nxw_atomic_contacts_5.0A.tab'
# '1tsu'
# '4lwy'
# '3p1o'
# '1ff0'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ly/1lyi_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/gr/3gr2_atomic_contacts_5.0A.tab'
# '4p4q'
# '1wzb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/am/5amg_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cz/5czw_atomic_contacts_5.0A.tab'
# '3zn8'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/d1/5d10_atomic_contacts_5.0A.tab'
# '4iaq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/l1/5l19_atomic_contacts_5.0A.tab'
# '1tzl'
# '3hu1'
# '2i40'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/u7/5u76_atomic_contacts_5.0A.tab'
# '4k4j'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fd/1fd2_atomic_contacts_5.0A.tab'
# '3d5s'
# '4rup'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/mf/3mfp_atomic_contacts_5.0A.tab'
# '6hwd'
# '2xpo'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/m0/2m07_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/31/131l_atomic_contacts_5.0A.tab'
# '1x7j'
# '5hcp'
# '5mdx'
# '2m8l'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cu/1cuc_atomic_contacts_5.0A.tab'
# '4kdo'
# '2off'
# '2qtn'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ck/1ckp_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/vd/1vd7_atomic_contacts_5.0A.tab'
# '4nfg'
# '1f2s'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/f7/1f7y_atomic_contacts_5.0A.tab'
# '4e9d'
# '3j8g'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/el/4el7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pd/5pdx_atomic_contacts_5.0A.tab'
# '1evr'
# '4p0a'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bs/3bsh_atomic_contacts_5.0A.tab'
# '5fvl'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ks/2ksj_atomic_contacts_5.0A.tab'
# '5ibr'
# '4a1u'
# '3w2t'
# '5wgd'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/m3/3m35_atomic_contacts_5.0A.tab'
# '1v8q'
# '1fyt'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ei/6eiu_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pn/5pno_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hx/5hx8_atomic_contacts_5.0A.tab'
# '2hkn'
# '2dlf'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/p6/3p6c_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ls/5lsg_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xa/4xa2_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fj/2fjn_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/e0/1e0n_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dm/6dmv_atomic_contacts_5.0A.tab'
# '1o1s'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dj/3dju_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ya/5yao_atomic_contacts_5.0A.tab'
# '4wzl'
# '2tgp'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/a4/3a43_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wk/2wkq_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/g4/1g49_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/a0/1a03_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/lk/5lkz_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fe/2fe9_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/g3/1g3c_atomic_contacts_5.0A.tab'
# '3mzg'
# '2de7'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/z5/5z5t_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xw/2xwy_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/e5/3e5i_atomic_contacts_5.0A.tab'
# '1hei'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zr/3zra_atomic_contacts_5.0A.tab'
# '4rwy'
# '4eqg'
# '2f4v'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ef/1efe_atomic_contacts_5.0A.tab'
# '3t8x'
# '3d0e'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/um/3umy_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ls/1ls2_atomic_contacts_5.0A.tab'
# '2v6t'
# '3mnv'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/es/1est_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cv/6cvj_atomic_contacts_5.0A.tab'
# '6hep'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ju/3jut_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/mz/2mzn_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/s0/1s03_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/49/149l_atomic_contacts_5.0A.tab'
# '3lru'
# '5tkk'
# '6ejn'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/go/3goi_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/a8/5a85_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zc/2zcb_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/n7/3n71_atomic_contacts_5.0A.tab'
# '1oz3'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/l1/1l1g_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/i2/5i2l_atomic_contacts_5.0A.tab'
# '5ck6'
# '5hy2'
# '1fin'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ms/4ms0_atomic_contacts_5.0A.tab'
# '4ops'
# '4gi0'
# '4gdo'
# '6huu'
# '4kiu'
# '1bd2'
# '3tl9'
# '3zfb'
# '3f5f'
# '5aqg'
# '3vti'
# '1bc2'
# '3n2r'
# '1hsa'
# '4cki'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hv/1hv7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/w5/4w59_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/p2/3p2v_atomic_contacts_5.0A.tab'
# '1lx5'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ba/3ba5_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/c7/3c7e_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/mu/3muv_atomic_contacts_5.0A.tab'
# '2i6r'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/a1/2a1m_atomic_contacts_5.0A.tab'
# '2rgn'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fx/6fx0_atomic_contacts_5.0A.tab'
# '4ilw'
# '3pl7'
# '2xk5'
# '6nm6'
# '5m3f'
# '4xnq'
# '3zcq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zb/3zbz_atomic_contacts_5.0A.tab'
# '1jth'
# '5xl2'
# '1d0o'
# '5nh9'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/og/5ogo_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fe/2fer_atomic_contacts_5.0A.tab'
# '5jl4'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/oh/4ohx_atomic_contacts_5.0A.tab'
# '1h28'
# '6mt3'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ao/6aok_atomic_contacts_5.0A.tab'
# '4adv'
# '4aid'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hv/1hvw_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pg/5pgt_atomic_contacts_5.0A.tab'
# '5cby'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/rt/1rtg_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/yo/1yog_atomic_contacts_5.0A.tab'
# '5ooy'
# '3b3p'
# '1h3p'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ei/5eic_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zw/4zwb_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/rw/1rw8_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/jo/5jo3_atomic_contacts_5.0A.tab'
# '6d5l'
# '1xtg'
# '3i5r'
# '3kzj'
# '4v6c'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/k9/2k91_atomic_contacts_5.0A.tab'
# '3j1n'
# '2oyi'
# '4m5z'
# '2xtj'
# '1mu8'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xo/4xol_atomic_contacts_5.0A.tab'
# '2mvx'
# '1hap'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/js/4jsz_atomic_contacts_5.0A.tab'
# '3q5j'
# '3kmj'
# '5aqm'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hu/3hu8_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/g0/1g0q_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zb/2zb0_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cg/1cgu_atomic_contacts_5.0A.tab'
# '5yvi'
# '4js9'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ze/4zet_atomic_contacts_5.0A.tab'
# '5d8h'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/p9/5p9k_atomic_contacts_5.0A.tab'
# '2pym'
# '2hpp'
# '6b2j'
# '4uer'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/na/1na1_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ps/5ps3_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dw/2dw2_atomic_contacts_5.0A.tab'
# '4ux8'
# '4a9j'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fe/3fe8_atomic_contacts_5.0A.tab'
# '2cnw'
# '1b27'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cq/2cqc_atomic_contacts_5.0A.tab'
# '1e1r'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cm/2cm8_atomic_contacts_5.0A.tab'
# '4mz5'
# '5fik'
# '1chi'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/a7/2a7i_atomic_contacts_5.0A.tab'
# '5wek'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ed/4ed2_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fy/2fyg_atomic_contacts_5.0A.tab'
# '1m5c'
# '3hxn'
# '3mrb'
# '6hcq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hr/1hrv_atomic_contacts_5.0A.tab'
# '4feb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/sp/1spe_atomic_contacts_5.0A.tab'
# '1aj7'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ur/1urn_atomic_contacts_5.0A.tab'
# '3jcs'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/yk/4ykt_atomic_contacts_5.0A.tab'
# '2de6'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/al/1alf_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/an/2anp_atomic_contacts_5.0A.tab'
# '2qzt'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wg/4wg7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zi/4zim_atomic_contacts_5.0A.tab'
# '5li0'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ow/4owh_atomic_contacts_5.0A.tab'
# '3j8j'
# '2q6w'
# '4gbi'
# '5nrv'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/kn/5knw_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ed/5edp_atomic_contacts_5.0A.tab'
# '3d1x'
# '5dlv'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ql/1ql2_atomic_contacts_5.0A.tab'
# '2m2p'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ed/3eda_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fj/3fj8_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pm/5pmj_atomic_contacts_5.0A.tab'
# '1kd7'
# '3apn'
# '2aj3'
# '4mqe'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/oe/4oew_atomic_contacts_5.0A.tab'
# '2bki'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pq/5pqb_atomic_contacts_5.0A.tab'
# '1mq8'
# '2mj5'
# '4mb2'
# '2ynr'
# '5adc'
# '4u1u'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ph/5phu_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/vv/2vvk_atomic_contacts_5.0A.tab'
# '5l5q'
# '1hiy'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pd/5pd7_atomic_contacts_5.0A.tab'
# '4zcb'
# '2bni'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/e8/5e8x_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ll/4llx_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zr/1zr5_atomic_contacts_5.0A.tab'
# '5l6a'
# '1tuh'
# '3zrk'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qe/5qe3_atomic_contacts_5.0A.tab'
# '5fqn'
# '1y35'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/m1/2m1r_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qc/1qcy_atomic_contacts_5.0A.tab'
# '3avk'
# '1tmc'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/on/3onc_atomic_contacts_5.0A.tab'
# '6epp'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/d5/4d5n_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cn/2cnf_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cc/7ccp_atomic_contacts_5.0A.tab'
# '5fq8'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/g5/1g5v_atomic_contacts_5.0A.tab'
# '3f7y'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/db/4dbu_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ph/5ph6_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/d2/5d2r_atomic_contacts_5.0A.tab'
# '4fqn'
# '1y8r'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b4/1b4d_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/eh/5ehv_atomic_contacts_5.0A.tab'
# '5a4m'
# '5u8q'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/x3/3x36_atomic_contacts_5.0A.tab'
# '2fi5'
# '2jix'
# '5c7f'
# '1q2o'
# '5l5u'
# '4y8p'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/po/5poy_atomic_contacts_5.0A.tab'
# '3ja1'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qg/5qg1_atomic_contacts_5.0A.tab'
# '2na6'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wc/2wcx_atomic_contacts_5.0A.tab'
# '1a4x'
# '4cqs'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/oa/2oa0_atomic_contacts_5.0A.tab'
# '2dn3'
# '1u8g'
# '3dx8'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/kv/2kv7_atomic_contacts_5.0A.tab'
# '4x65'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/kn/3kne_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bh/3bhi_atomic_contacts_5.0A.tab'
# '5if3'
# '3ow2'
# '1str'
# '6haw'
# '5lxs'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dq/3dqc_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ms/4mse_atomic_contacts_5.0A.tab'
# '5iz8'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ka/1kaz_atomic_contacts_5.0A.tab'
# '1st0'
# '5is9'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zc/5zca_atomic_contacts_5.0A.tab'
# '5ed3'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b5/3b5r_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/tf/5tfb_atomic_contacts_5.0A.tab'
# '1r5k'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fl/2fla_atomic_contacts_5.0A.tab'
# '5l70'
# '1y85'
# '5bxn'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wg/1wg3_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xy/1xyh_atomic_contacts_5.0A.tab'
# '2e1z'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/v3/5v39_atomic_contacts_5.0A.tab'
# '1n1j'
# '6bcq'
# '6b4v'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/tm/5tmh_atomic_contacts_5.0A.tab'
# '3d25'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pd/3pdn_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/e2/1e2u_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bk/2bkq_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/uw/4uwc_atomic_contacts_5.0A.tab'
# '2ibx'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wh/4whw_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fn/2fnw_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/uv/3uvd_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qi/1qib_atomic_contacts_5.0A.tab'
# '3s9s'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/j1/5j1h_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/el/4el3_atomic_contacts_5.0A.tab'
# '1scz'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ny/4ny9_atomic_contacts_5.0A.tab'
# '5epj'
# '1tmt'
# '1xqh'
# '6gkf'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hp/6hpz_atomic_contacts_5.0A.tab'
# '1n6j'
# '4hnp'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/l5/2l5d_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ee/5eec_atomic_contacts_5.0A.tab'
# '1hga'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ki/1ki0_atomic_contacts_5.0A.tab'
# '4h1h'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/vq/2vqw_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/io/1io5_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ft/1ftj_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zo/2zo2_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bh/6bh5_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bw/6bwn_atomic_contacts_5.0A.tab'
# '5lfe'
# '4w99'
# '6idm'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b0/2b02_atomic_contacts_5.0A.tab'
# '3hus'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ro/3roy_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/jb/4jb4_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xj/2xjv_atomic_contacts_5.0A.tab'
# '3l0j'
# '3cme'
# '2c23'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pg/5pgn_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fk/2fkh_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/md/2mdz_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ur/1urf_atomic_contacts_5.0A.tab'
# '5h9f'
# '1kj3'
# '2znp'
# '4uo5'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b3/5b3w_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/sp/2spn_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nx/5nxg_atomic_contacts_5.0A.tab'
# '3k51'
# '2m2m'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pe/1pet_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b1/2b1m_atomic_contacts_5.0A.tab'
# '1qaw'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/gh/3ghs_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/yx/5yxb_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/t3/1t3p_atomic_contacts_5.0A.tab'
# '4dqm'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/aa/5aaa_atomic_contacts_5.0A.tab'
# '3spv'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ki/4kip_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wh/2who_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/it/4itf_atomic_contacts_5.0A.tab'
# '5fge'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/rn/2rn5_atomic_contacts_5.0A.tab'
# '5dvm'
# '6dhe'
# '5vni'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/rd/3rdq_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/i7/1i7k_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/f3/6f30_atomic_contacts_5.0A.tab'
# '2b10'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nh/4nhs_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/o3/1o30_atomic_contacts_5.0A.tab'
# '3ey4'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ia/4iar_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wt/2wtd_atomic_contacts_5.0A.tab'
# '2q6s'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/lf/2lfo_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/od/2odu_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/sc/3sc0_atomic_contacts_5.0A.tab'
# '2mpz'
# '5nhu'
# '1gpo'
# '5hyr'
# '5ib3'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pj/5pj8_atomic_contacts_5.0A.tab'
# '4kla'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/kp/5kpi_atomic_contacts_5.0A.tab'
# '3blr'
# '2xxh'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cn/1cny_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/db/4dbs_atomic_contacts_5.0A.tab'
# '1d5m'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/da/6das_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/of/1ofc_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/k5/1k5m_atomic_contacts_5.0A.tab'
# '2hg5'
# '3rt3'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xb/1xb8_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/sv/3svh_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qd/5qdh_atomic_contacts_5.0A.tab'
# '6avo'
# '5vqt'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ek/4ek5_atomic_contacts_5.0A.tab'
# '1pcg'
# '1heg'
# '3hkb'
# '1qqa'
# '2fdb'
# '1ygu'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/iv/4ivb_atomic_contacts_5.0A.tab'
# '4v4f'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xh/2xhx_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/gs/4gs8_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/mt/4mtb_atomic_contacts_5.0A.tab'
# '1rfq'
# '1h8h'
# '4v8q'
# '3mtd'
# '1bxs'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/q6/3q6k_atomic_contacts_5.0A.tab'
# '1f8a'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zk/2zku_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/rq/2rq4_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cq/2cqu_atomic_contacts_5.0A.tab'
# '4wi7'
# '4jna'
# '2lvo'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/e8/2e8z_atomic_contacts_5.0A.tab'
# '1fqv'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/lf/1lfo_atomic_contacts_5.0A.tab'
# '5wyk'
# '2o2r'
# '3kz8'
# '4hkd'
# '3syp'
# '4j70'
# '5x0r'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/l1/2l1m_atomic_contacts_5.0A.tab'
# '1qmb'
# '4ewx'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/o3/1o3a_atomic_contacts_5.0A.tab'
# '5njg'
# '5nv2'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qy/2qyq_atomic_contacts_5.0A.tab'
# '3utt'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ps/5psl_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pb/5pbv_atomic_contacts_5.0A.tab'
# '6f3r'
# '1rd8'
# '1bml'
# '2qn6'
# '4mq7'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/az/3az3_atomic_contacts_5.0A.tab'
# '4zdr'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bx/4bxq_atomic_contacts_5.0A.tab'
# '3kfp'
# '6meh'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/gj/3gj2_atomic_contacts_5.0A.tab'
# '3nw2'
# '1mkx'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xz/5xzs_atomic_contacts_5.0A.tab'
# '3kmf'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/t2/3t2s_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ud/3ud7_atomic_contacts_5.0A.tab'
# '6faz'
# '2c3c'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/o4/2o4w_atomic_contacts_5.0A.tab'
# '5ixd'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/oe/5oer_atomic_contacts_5.0A.tab'
# '2mjv'
# '5apo'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ik/2ikj_atomic_contacts_5.0A.tab'
# '1ida'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/an/5ani_atomic_contacts_5.0A.tab'
# '4qrq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/my/1myf_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/oz/2ozq_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xv/4xvd_atomic_contacts_5.0A.tab'
# '5y5y'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hz/3hzf_atomic_contacts_5.0A.tab'
# '3lqa'
# '3mjl'
# '3n56'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ie/4ieu_atomic_contacts_5.0A.tab'
# '6b7y'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ap/3apq_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/om/5omo_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/tc/3tc5_atomic_contacts_5.0A.tab'
# '2nyt'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/te/1te3_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/j1/2j14_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/a9/3a96_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cc/4ccu_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fn/5fnk_atomic_contacts_5.0A.tab'
# '1du3'
# '3gmq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pm/5pmg_atomic_contacts_5.0A.tab'
# '4yma'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/lj/2lj5_atomic_contacts_5.0A.tab'
# '3fxv'
# '5aqu'
# '2g0g'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/iu/3iu6_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ma/5mag_atomic_contacts_5.0A.tab'
# '2ja5'
# '3exg'
# '4yyz'
# '2j7x'
# '2ia0'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b9/1b9f_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/u1/1u1y_atomic_contacts_5.0A.tab'
# '2otl'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/yf/4yfq_atomic_contacts_5.0A.tab'
# '5aqs'
# '3nmz'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/r6/1r6h_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bj/1bjb_atomic_contacts_5.0A.tab'
# '1t6u'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/f6/2f6y_atomic_contacts_5.0A.tab'
# '3ols'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qg/3qgh_atomic_contacts_5.0A.tab'
# '4l0n'
# '4k76'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nh/4nh8_atomic_contacts_5.0A.tab'
# '3vjs'
# '1zhb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dv/6dvl_atomic_contacts_5.0A.tab'
# '5uym'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/g3/6g3q_atomic_contacts_5.0A.tab'
# '1b6q'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/in/2ine_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ml/1mlk_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/04/104m_atomic_contacts_5.0A.tab'
# '2iwg'
# '3t1p'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dk/4dkr_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/mt/3mt5_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/eg/5egb_atomic_contacts_5.0A.tab'
# '2gdc'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nk/1nkc_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ut/5ut7_atomic_contacts_5.0A.tab'
# '3i00'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/vp/2vpl_atomic_contacts_5.0A.tab'
# '6bnu'
# '3v5k'
# '1miu'
# '3avm'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wd/4wdu_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ii/5iid_atomic_contacts_5.0A.tab'
# '1kiq'
# '1tkt'
# '1utu'
# '4mxq'
# '4hgc'
# '1rcb'
# '3i6w'
# '1dkf'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/em/2em6_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/td/1tdl_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/i8/5i8q_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pi/5pia_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ds/5dsk_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/go/6goj_atomic_contacts_5.0A.tab'
# '4f0z'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b7/4b7p_atomic_contacts_5.0A.tab'
# '5l9t'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/py/1pyc_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/c5/1c5p_atomic_contacts_5.0A.tab'
# '4atx'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xv/4xve_atomic_contacts_5.0A.tab'
# '6b8m'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/k4/2k4d_atomic_contacts_5.0A.tab'
# '4xro'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/yd/4yda_atomic_contacts_5.0A.tab'
# '2vis'
# '3p1j'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qg/5qgd_atomic_contacts_5.0A.tab'
# '5ov7'
# '3ejh'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cj/3cj0_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fm/3fmm_atomic_contacts_5.0A.tab'
# '5xlt'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/tf/5tf8_atomic_contacts_5.0A.tab'
# '2ovh'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/uw/4uwb_atomic_contacts_5.0A.tab'
# '1g6q'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/yp/1yp9_atomic_contacts_5.0A.tab'
# '3cz2'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xz/1xzl_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/k8/2k8c_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/j1/4j1a_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pf/5pf8_atomic_contacts_5.0A.tab'
# '4d8p'
# '5ajk'
# '3e1i'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qw/6qwx_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/mx/4mxl_atomic_contacts_5.0A.tab'
# '3fvd'
# '5o35'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/q3/1q32_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pj/5pjz_atomic_contacts_5.0A.tab'
# '5krj'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/q8/4q8e_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/g2/5g26_atomic_contacts_5.0A.tab'
# '5nhd'
# '5g0x'
# '6cp6'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/re/4rex_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/uy/1uy6_atomic_contacts_5.0A.tab'
# '4uo9'
# '5mak'
# '5l9u'
# '3hql'
# '3qje'
# '6amo'
# '1hxw'
# '5vun'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/y9/1y9r_atomic_contacts_5.0A.tab'
# '3t1b'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/k4/2k4e_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/v4/5v46_atomic_contacts_5.0A.tab'
# '4u7q'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/vz/3vzk_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/kh/5khz_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ng/1ngr_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/yo/5you_atomic_contacts_5.0A.tab'
# '6g2i'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b2/3b28_atomic_contacts_5.0A.tab'
# '1nu7'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pf/5pfj_atomic_contacts_5.0A.tab'
# '6a92'
# '2vbq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/n1/2n1v_atomic_contacts_5.0A.tab'
# '7gss'
# '3g4x'
# '3zmq'
# '3wbk'
# '3gct'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/xj/4xjd_atomic_contacts_5.0A.tab'
# '1k6f'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pt/5pt1_atomic_contacts_5.0A.tab'
# '1h9u'
# '2h3n'
# '5lvf'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/h0/3h06_atomic_contacts_5.0A.tab'
# '3tt8'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/rj/4rjl_atomic_contacts_5.0A.tab'
# '1lts'
# '5lzy'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/i8/4i8s_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/oa/4oa7_atomic_contacts_5.0A.tab'
# '3vdc'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ed/4ed6_atomic_contacts_5.0A.tab'
# '2bnp'
# '4ahr'
# '3my1'
# '4x34'
# ...
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wo/4wo6_atomic_contacts_5.0A.tab'
# '4zox'
# '5aul'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ig/5ig6_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/n6/1n6c_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/o7/4o7c_atomic_contacts_5.0A.tab'
# '3qwz'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pz/5pzc_atomic_contacts_5.0A.tab'
# '2cjm'
# '2h6p'
# '5v8i'
# '3p35'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/c7/6c7z_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wi/1wip_atomic_contacts_5.0A.tab'
# '3dok'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dx/4dxb_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/a7/5a7o_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/u0/5u04_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/np/3np3_atomic_contacts_5.0A.tab'
# '5a6a'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/sd/3sdn_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/gb/6gbi_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/m2/5m2f_atomic_contacts_5.0A.tab'
# '2al4'
# '1yzi'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/i5/1i57_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/vm/3vm0_atomic_contacts_5.0A.tab'
# '1obx'
# '3chv'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qi/2qim_atomic_contacts_5.0A.tab'
# '1hyr'
# '1iz3'
# '1dx5'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nh/6nhd_atomic_contacts_5.0A.tab'
# '1itg'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/l9/5l99_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ap/5apc_atomic_contacts_5.0A.tab'
# '1o7d'
# '4c9b'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ef/3ef7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wu/2wu7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/d8/6d8e_atomic_contacts_5.0A.tab'
# '2g9h'
# '3puz'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/e0/6e0d_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ih/5ihg_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ot/4otf_atomic_contacts_5.0A.tab'
# '2int'
# '4aye'
# '3x14'
# '1vgc'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/z4/4z41_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/jw/5jwv_atomic_contacts_5.0A.tab'
# '5cmx'
# '5ob2'
# '4by1'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bf/2bfq_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fl/3fln_atomic_contacts_5.0A.tab'
# '4pji'
# '5tqr'
# '5g46'
# '6enb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bq/4bqb_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ei/4ei4_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ca/2cab_atomic_contacts_5.0A.tab'
# '4u5f'
# '6a1v'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/h9/4h9a_atomic_contacts_5.0A.tab'
# '2h4f'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/26/126l_atomic_contacts_5.0A.tab'
# '4zif'
# '2c5x'
# '1ifs'
# '1r4o'
# '3fvh'
# '2f5v'
# '5uny'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b8/2b86_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b6/4b6v_atomic_contacts_5.0A.tab'
# '3t19'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ko/4koc_atomic_contacts_5.0A.tab'
# '4rg5'
# '1agc'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bf/1bfb_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pi/5pil_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/am/1aml_atomic_contacts_5.0A.tab'
# '2qwq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/i8/1i8g_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/kh/5kh7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b4/4b49_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/py/5pyp_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dz/1dzf_atomic_contacts_5.0A.tab'
# '5nwx'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ek/4ekp_atomic_contacts_5.0A.tab'
# '1m74'
# '6em3'
# '5n1y'
# '4ila'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ei/6ein_atomic_contacts_5.0A.tab'
# '1hcy'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/rm/2rmw_atomic_contacts_5.0A.tab'
# '5d5m'
# '3wg7'
# '3i40'
# '5tsj'
# '2qcb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/l9/2l9m_atomic_contacts_5.0A.tab'
# '2pwm'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pe/3pen_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/w1/3w1d_atomic_contacts_5.0A.tab'
# '5uq8'
# '1a9w'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ab/4abg_atomic_contacts_5.0A.tab'
# '5fb6'
# '5kk3'
# '4ht1'
# '2i7s'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/od/5odx_atomic_contacts_5.0A.tab'
# '4qwg'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/z3/1z3u_atomic_contacts_5.0A.tab'
# '4q6i'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pk/5pk1_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zc/5zc4_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/62/162l_atomic_contacts_5.0A.tab'
# '4bgw'
# '1rps'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bl/2blx_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zy/4zyi_atomic_contacts_5.0A.tab'
# '2a2s'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/gc/4gcf_atomic_contacts_5.0A.tab'
# '4fwo'
# '2nx5'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/px/5px3_atomic_contacts_5.0A.tab'
# '1jyq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ph/3phu_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/d0/6d0s_atomic_contacts_5.0A.tab'
# '6d3y'
# '4u3m'
# '6es9'
# '5bry'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/hq/6hq0_atomic_contacts_5.0A.tab'
# '4wwc'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/jc/1jci_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fs/1fsh_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/h5/3h5s_atomic_contacts_5.0A.tab'
# '2vdr'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ex/6ex1_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/s0/3s0z_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cb/1cbs_atomic_contacts_5.0A.tab'
# '3ghg'
# '4b1t'
# '1i1r'
# '3wu2'
# '4g5g'
# '6cex'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ll/5llg_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nv/5nv7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wr/5wr9_atomic_contacts_5.0A.tab'
# '4v1o'
# '4exm'
# '5djd'
# '4pjb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ed/2edb_atomic_contacts_5.0A.tab'
# '1w7t'
# '4u21'
# '5l5r'
# '1m7z'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wu/5wuu_atomic_contacts_5.0A.tab'
# '3qe1'
# '4hww'
# '1de4'
# '3cgh'
# '4o6w'
# '4gir'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/pt/5pt5_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ea/2eau_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/jt/2jty_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/am/1am6_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/wb/1wbr_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/eh/2ehr_atomic_contacts_5.0A.tab'
# '4oh8'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dq/6dq4_atomic_contacts_5.0A.tab'
# '3ciq'
# '4e0r'
# '3nzi'
# '1m00'
# '5g6e'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ic/5ic0_atomic_contacts_5.0A.tab'
# '4ckx'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/b7/2b74_atomic_contacts_5.0A.tab'
# '4ie2'
# '2qxm'
# '4v3y'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/at/6ato_atomic_contacts_5.0A.tab'
# '5ftl'
# '4qu5'
# '2chb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/g2/1g2n_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qo/2qo6_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ka/4kag_atomic_contacts_5.0A.tab'
# '4nqk'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/mu/2mum_atomic_contacts_5.0A.tab'
# '4r4k'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/m1/3m1w_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/os/1os5_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/qp/2qpa_atomic_contacts_5.0A.tab'
# '6bmt'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dp/6dpo_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ee/6eea_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/ha/6hak_atomic_contacts_5.0A.tab'
# '3q0t'
# '4u1s'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/cp/1cp0_atomic_contacts_5.0A.tab'
# '4ckz'
# '5kaq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/tr/1tr7_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/x7/2x7u_atomic_contacts_5.0A.tab'
# '5jhr'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/s8/3s8s_atomic_contacts_5.0A.tab'
# '1efx'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/o8/3o8z_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/04/104l_atomic_contacts_5.0A.tab'
# '5hrq'
# '2pld'
# '5kpx'
# '1beo'
# '5x4l'
# '4ibp'
# '6grs'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/zw/2zwt_atomic_contacts_5.0A.tab'
# '2ny2'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/oi/2oih_atomic_contacts_5.0A.tab'
# '5j89'
# '5vmf'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/fa/6faf_atomic_contacts_5.0A.tab'
# '4ncq'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/lo/4lo9_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/nb/2nbh_atomic_contacts_5.0A.tab'
# '4mgb'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/dv/4dvv_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/kg/5kgr_atomic_contacts_5.0A.tab'
# [Errno 2] No such file or directory: '/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/bw/4bw1_atomic_contacts_5.0A.tab'
# '5b83'
