# %%
#NOTES:
#To get a list of PDB that contains histones from 'text.csv':
#cut -f1 text.tsv | uniq | awk '{print tolower($0)}' | sort

#text.tsv should be sorted by pdb and then uniprot name
#it MUST have 'NA' in uniprot and name blanks

# %%
#!/usr/bin/env python 3
import re

#PATH = "../data/Interfaces/"
PATH = "/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/"
CHAIN_FILE = "text.tsv"
PDB_LIST = "pdbList.txt"

# %%
#PARAMETERS:
#fils is a string with path to the file to be checked

#RESULTS:
#Returns 1 or 0 depending on file existence 


def file_check(file):
    
    try:
        open(file, "r")
        return 1
    
    except IOError:
        print("Error: " + file + " does not appear to exist.")
        return 0

# %%
#PARAMETERS:
#name is a string with the name of chain
#typeCount is a 2-element list with the first one being an empty string and the second - 0 (iteger)

#RESULTS:
#Updates the typeCount array: the first element = general histone type(s); the second element = (should be) number of histones in chain

def is_histone(name, typeCount):

    if(not re.search(r'chaperone|ase|binding|p53 peptide|non-histone|jmjc|rna|synth', name, re.I)):
        if(re.search(r'histone.*h?\d|h?\d.*histone|h?\d.*histone-like|histone-like.*h?\d|histone macro.*h?\d|h?\d.*histone macro|h?\d.*\speptide|\speptide.*h?\d|h3k4me0|h3(1-9)k4me3|$h\d^|archaeal histone|histone peptide', name, re.I)):
            typeCount[1] = 1 #adds the number of histones in chain  (should be changed to actual number of histones in chain)

            if(re.search(r'h2a', name, re.I)):
                typeCount[0] += 'h2a#'
                
            elif(re.search(r'h2b', name, re.I)):
                typeCount[0] += 'h2b#'
                    
            elif(re.search(r'h3', name, re.I)):
                typeCount[0] += 'h3#'
                    
            elif(re.search(r'h4', name, re.I)):
                typeCount[0] += 'h4#'
                    
            elif(re.search(r'h1', name, re.I)):
                typeCount[0] += 'h1#'  
                    
            elif(re.search(r'h5', name, re.I)):
                typeCount[0] += 'h5#'
                    
            else:
                typeCount[0] += 'some histone#'

# %%
#PARAMETERS: 
#pdbList is a text file with a header and one column PDB
#files is a list
#parameter is a string, either 'mapping' or 'interface' depending on desired results

#RESULTS:
#A list of absolute paths to either mapping files or interface files as it is stored on local NCBI machines


def get_files(pdbList, files, parameter):
    
    with open(pdbList, 'r') as pfh:
        pfh.readline()
        
        if(parameter == 'mapping'):
            
            for line in pfh:
                line = line.strip()
                folder = line[1] + line[2] 
                files.append(PATH + folder + '/' + line + '_chain_protein_mapping.tab')
                
        elif(parameter == 'interface'): 
            
            for line in pfh:
                line = line.strip()
                folder = line[1] + line[2]
                files.append(PATH + folder + '/' + line + '_atomic_contacts_5.0A.tab')

# %%
#PARAMETERS: 
#pdb is a string with pdb id
#parameter is a string, either 'mapping' or 'interface' depending on desired results

#RESULTS:
#An absolute paths to either mapping file or interface file as it is stored on local NCBI machines


def get_file(pdb, parameter):
    
    if(parameter == 'mapping'):
        folder = pdb[1] + pdb[2] 
        file = (PATH + folder + '/' + pdb + '_chain_protein_mapping.tab')
        return file  
        
    elif(parameter == 'interface'): 
        folder = pdb[1] + pdb[2]
        file = (PATH + folder + '/' + pdb + '_atomic_contacts_5.0A.tab')
        return file

# %%
#PARAMETERS:
#cFile is tab-separated file with a header and 4 columns: pdb, chain, uniprot, name
#dictionary is nested with the innermost dict being dictionary['pdb'] = {}

#RESULTS:
#The format of the end-product dictionary is: {pdb : {AlexChain: myChain#UNIPROT#name#type#nucleosome(bool)#bindingPartner(bool)}}
#Example: {1alq : {'G': 'E#P02302#Histone H3.3C#H3#1#0'}}


def get_chain_dictionaries(cFile, dictionary): 
    
    with open(cFile, 'r') as cfh:
        cfh.readline()
        
        histoneCount = {} #is used to count number of histones in a structure!!!!!!!
        
        tempDict = {}
        tempDict['pdb'] = {}
            
        mappingFiles = [] 
        get_files(PDB_LIST, mappingFiles, 'mapping')
        
        
        
        
        for file in mappingFiles:
            try: #adds a pdb entry to the dict only if mapping file exists

                with open(file, 'r') as mfh:
                    mfh.readline() #skips header
                    pdb = file.split('/')[-1].split('_', 1)[0]

                    for mLine in mfh:
                        chainPair = mLine.split('\t', 2)
                        alexChain = chainPair[0]
                        myChain = chainPair[1]
                        
                        if(pdb in tempDict):
                            tempDict[pdb][alexChain] = myChain
                        else:
                            tempDict[pdb] = {alexChain : myChain}

            except IOError:
                pass
                #print("Error: " + mappingFile + " does not appear to exist.")
        
        
        
        
        for cLine in cfh:           
            fields = cLine.strip().split('\t')
            
            pdb = fields[0]
    
            if(pdb in tempDict): #continues only if a mapping file exists
                chain = fields[1]
                uniprot = fields[2]
                name = fields[3]


                histoneTypeAndCount = ['', 0]

                is_histone(name, histoneTypeAndCount) #checks whether the name looks like a histone!!!!!!!!!

                tempType = histoneTypeAndCount[0]
                tempCount = histoneTypeAndCount[1]
                
                
                #######################
                if(tempCount):
                    
                    if(pdb in histoneCount):
                        
                        if(tempType not in histoneCount[pdb]):
                            histoneCount[pdb].append(tempType) #!!!!!!

                    else:
                        histoneCount[pdb] = [tempType]

                        
                        
                        
                try: #adds a chain entry to the dict only if there exists a corresponding chain in the mapping file
                    alexChain = list(tempDict[pdb].keys())[list(tempDict[pdb].values()).index(chain)]

                    if(pdb in dictionary):

                        if(tempCount): #checks if chain is a histone!!!!
                            dictionary[pdb][alexChain] = str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + tempType #!!!!

                        else: #!!!!
                            dictionary[pdb][alexChain] = str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + 'other#' #!!!!

                    else:

                        if(tempCount): #checks if chain is a histone!!!!
                            dictionary[pdb] = {alexChain : str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + tempType} #!!!!

                        else: #!!!!
                            dictionary[pdb] = {alexChain : str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + 'other#'} #!!!!
                        
                except ValueError:
                    #print("Error: " + ValueError + ", in " + pdb)               
                    pass

                    
                    
                    
        for structure in histoneCount:
            partnerFlag = 0 ###
            uniqueHistoneNum = len(histoneCount[structure])
            
            if(uniqueHistoneNum > 3): #checks if pdb has at least a half of nucleosome!!!!!!!
                
                for chain in dictionary[structure]:
                    chainFields = dictionary[structure][chain].split('#')

                    chainType = chainFields[-2]
                    chainName = chainFields[1] + '\t' + chainFields[2]

                    dictionary[structure][chain] += '1#' #!!!!!!
                    
                    if(partnerFlag == 0 and chainType == 'other'):
                        #print('\t\t\t\t\t' + structure + '\t' + 'nucleosome' + '\t' + chainName)
                        partnerFlag = 1
                    
                if(partnerFlag == 0):
                    dictionary[structure][chain] += '0'
                    print(structure + '\t' + 'nucleosome' + '\t' + 'no bp')
                    
                else:
                    dictionary[structure][chain] += '1'
                    print(structure + '\t' + 'nucleosome' + '\t' + 'yes bp')
            
            else: #!!!!!!

                for chain in dictionary[structure]: #!!!!!
                    chainFields = dictionary[structure][chain].split('#')
                    
                    chainType = chainFields[-2]
                    chainName = chainFields[1] + '\t' + chainFields[2]
                    
                    dictionary[structure][chain] += '0#' #!!!!!! 

                    if(partnerFlag == 0 and chainType == 'other'):
                        #print('\t\t\t\t\t' + structure + '\t' + 'histone' + '\t' + chainName)
                        partnerFlag = 1

                if(partnerFlag == 0):
                    dictionary[structure][chain] += '0'
                    print(structure + '\t' + 'histone' + '\t' + 'no bp')

                else:
                    dictionary[structure][chain] += '1'
                    print(structure + '\t' + 'histone' + '\t' + 'yes bp')

# %%
#PARAMETERS:
#interfaceFiles is a list of strings containing names of interface files
#chainDictionary is a dictionary produced by 'get_chain_dictionaries'
#interfaceDictonary is a nested dictionary with the innermost dict being interfaceDictionary['uniprotPair'] = {}, where the values are lists of the next form [chain pair data, residue number, pdb IDs] 
#Example: 'P84233@P62799': {'44': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla$q5cl']
#note that data fields of a chain is separated by #, @ separates chains binding partner chains, $ separates chain pairs and pdb structures


def residue_count(interfaceFiles, chainDictionary, interfaceDictionary):
    for file in interfaceFiles:
        pdb = file.split('/')[-1].split('_', 1)[0] 
        
        try:
            with open (file, 'r') as ifh:
                ifh.readline() #skips header

                for line in ifh:
                    lineFields = line.split('\t', 6) #gets only the first 8 columns !!!

                    chain1 = lineFields[0].split('_', 1)[0] # the split part treats biological assembly chains as separate chains ???
                    chain2 = lineFields[4].split('_', 1)[0]

                    residue1 = lineFields[2]
                    residue2 = lineFields[5]

                    uniprot1 = chainDictionary[pdb][chain1].split('#', 2)[1]
                    uniprot2 = chainDictionary[pdb][chain2].split('#', 2)[1]

                    uniprotPair1 = uniprot1 + '@' + uniprot2
                    uniprotPair2 = uniprot2 + '@' + uniprot1

                    chainPair1 = chainDictionary[pdb][chain1] + '@' + chainDictionary[pdb][chain2]
                    chainPair2 = chainDictionary[pdb][chain2] + '@' + chainDictionary[pdb][chain1]

                    if(uniprotPair1 in interfaceDictionary):

                        if(residue1 in interfaceDictionary[uniprotPair1]):
                            interfaceDictionary[uniprotPair1][residue1][1] += 1  

                            if(chainPair1 not in interfaceDictionary[uniprotPair1][residue1][0]):
                                interfaceDictionary[uniprotPair1][residue1][0] += '$' + chainPair1                       
                                
                                if(pdb not in interfaceDictionary[uniprotPair1][residue1][2]):
                                    interfaceDictionary[uniprotPair1][residue1][2] += '$' + pdb
                                   
                        else:
                            interfaceDictionary[uniprotPair1][residue1] = [chainPair1, 1, pdb]    #format of the innermost dict        

                    elif(uniprotPair2 in interfaceDictionary):

                        if(residue2 in interfaceDictionary[uniprotPair2]):
                            interfaceDictionary[uniprotPair2][residue2][1] += 1

                            if(chainPair2 not in interfaceDictionary[uniprotPair2][residue2][0]):
                                interfaceDictionary[uniprotPair2][residue2][0] += '$' + chainPair2                        

                                if(pdb not in interfaceDictionary[uniprotPair2][residue2][2]):
                                    interfaceDictionary[uniprotPair2][residue2][2] += '$' + pdb
                                    
                        else:
                            interfaceDictionary[uniprotPair2][residue2] = [chainPair2, 1, pdb]

                    else:
                         interfaceDictionary[uniprotPair1] = {residue1 : [chainPair1, 1, pdb]}  
                            
        except IOError:
            #print("Error: " + interfaceFile + " does not appear to exist.")
            pass

# %%
def normalize_count(interfaceDictionary):
    
    for pair in interfaceDictionary:
        
        for residue in interfaceDictionary[pair]:
            pdbCount = len(interfaceDictionary[pair][residue][2].split('$'))
            interfaceDictionary[pair][residue].append(interfaceDictionary[pair][residue][1] / pdbCount) #[3] is normalized by uniprot pair

# %%
def average_histones(interfaceDictionary):
    
    avgDict = {}
    avgDict['type'] = {}

    for pair in interfaceDictionary:
        
        for residue in interfaceDictionary[pair]:                           
            targetFields = interfaceDictionary[pair][residue][0].split('@')[0].split('#')
            sourceFields = interfaceDictionary[pair][residue][0].split('@')[-1].split('#')
            
            if(targetFields[-2] != 'other' and targetFields[-3] != 'other'): #MAKE ENTRIES HAVE THE SAME NUMBER OF ELEMENTS!!!
                histoneType = targetFields[3]
                normalizedCount = interfaceDictionary[pair][residue][3]
                
                if(histoneType in avgDict):
                    
                    if(residue in avgDict[histoneType]):
                        avgDict[histoneType][residue] += normalizedCount
                    
                    else:
                        avgDict[histoneType][residue] = normalizedCount
                        
                else:
                    avgDict[histoneType] = {residue : normalizedCount}
                    
            elif(sourceFields[-2] != 'other' and sourceFields[-3] != 'other'):#MAKE ENTRIES HAVE THE SAME NUMBER OF ELEMENTS!!!
                histoneType = sourceFields[3]
                normalizedCount = interfaceDictionary[pair][residue][3]
                
                if(histoneType in avgDict):
                    
                    if(residue in avgDict[histoneType]):
                        avgDict[histoneType][residue] += normalizedCount
                    
                    else:
                        avgDict[histoneType][residue] = normalizedCount
                        
                else:
                    avgDict[histoneType] = {residue : normalizedCount}
    
    return avgDict

# %%
def sum_contacts(interfaceDictionary):
    
    sumDict = {}

    for pair in interfaceDictionary:
        if(pair != 'uniprotPair'):

            randomResidue = list(interfaceDictionary[pair].keys())[0]

            targetFields = interfaceDictionary[pair][randomResidue][0].split('@')[0].split('#')
            sourceFields = interfaceDictionary[pair][randomResidue][0].split('@')[-1].split('#')
            
            pdbList = []
            for residue in interfaceDictionary[pair]:
                pdbIDs = interfaceDictionary[pair][residue][2].split('$')
                
                for pdb in pdbIDs:
                    
                    if(pdb not in pdbList):
                        pdbList.append(pdb)
            
            #print(pair, '\t', pdbList)
            
            interfaceFlag = 0
            
            if(targetFields[-2] != 'other' and targetFields[-3] != 'other'):
                histoneType = targetFields[3]
                    
                newPair = histoneType + '@'
                
                if(sourceFields[-2] != 'other' and sourceFields[-3] != 'other'):
                    histoneType2 = sourceFields[3]
                                 
                    newPair += histoneType2
                    
                else:   
                    for field in sourceFields:
                        newPair += field + '#'
                        interfaceFlag = 1
                        
                totalCount = 0

                for residue in interfaceDictionary[pair]:
                    normalizedCount = interfaceDictionary[pair][residue][3]
                    totalCount += normalizedCount
                
                if(newPair in sumDict):
                    sumDict[newPair][0] += totalCount
                
                else:
                    sumDict[newPair] = [totalCount, pdbList]

            elif(sourceFields[-2] != 'other' and sourceFields[-3] != 'other'):
                histoneType = sourceFields[3]
                
                newPair = histoneType + '@'
                    
                for field in targetFields:
                    newPair += field + '#'                 
                    
                totalCount = 0

                for residue in interfaceDictionary[pair]:
                    normalizedCount = interfaceDictionary[pair][residue][3]
                    totalCount += normalizedCount

                if(newPair in sumDict):
                    sumDict[newPair][0] += totalCount
                
                else:
                    sumDict[newPair] = [totalCount, pdbList]
                    
            else:
                newPair = ''
                
                for field in targetFields:
                    newPair += field + '#'
                    
                newPair += '@'
                
                for field in sourceFields:
                    newPair += field + '#'    
                   
                totalCount = 0

                for residue in interfaceDictionary[pair]:
                    normalizedCount = interfaceDictionary[pair][residue][3]
                    totalCount += normalizedCount

                if(newPair in sumDict):
                    sumDict[newPair][0] += totalCount
                
                else:
                    sumDict[newPair] = [totalCount, pdbList]
            
            #####Have to account for the case when an interface between two non-histone chains is already in the dictionary, but is stored in a reverse order!!!!

    return sumDict

# %%
def main():
    chainDictionary = {}
    chainDictionary['chain'] = {}
    
    get_chain_dictionaries(CHAIN_FILE, chainDictionary)
    
    interfaceFiles = []
    get_files(PDB_LIST, interfaceFiles, 'interface')
    
    interfaceDictionary = {}
    interfaceDictionary['uniprotPair'] = {}
    
    residue_count(interfaceFiles, chainDictionary, interfaceDictionary)
    
    normalize_count(interfaceDictionary)
    #for pair in interfaceDictionary:
    #    print(pair + ': ' + str(interfaceDictionary[pair]))
    #    print('\n')
    
    avgDict = average_histones(interfaceDictionary)
    #print(avgDict)    
    
    sumDict = sum_contacts(interfaceDictionary)
    print('target' + '\t' + 'source' + '\t' + 'contacts')
    pdbList = '1aoi,1eqz,1f66,1hio,1hq3,1id3,1kx3,1kx4,1kx5,1m18,1m19,1m1a,1p34,1p3a,1p3b,1p3f,1p3g,1p3i,1p3k,1p3l,1p3m,1p3o,1p3p,1s32,1tzy,1u35,1zbb,2aro,2cv5,2f8n,2fj7,2hio,2nqb,2nzd,2pyo,3a6n,3afa,3an2,3av1,3av2,3ayw,3aze,3azf,3azg,3azh,3azi,3azj,3azk,3azl,3azm,3azn,3b6f,3b6g,3c1b,3c1c,3kuy,3kwq,3kxb,3lel,3lja,3lz0,3lz1,3mgp,3mgq,3mgr,3mgs,3mnn,3mvd,3o62,3reh,3rei,3rej,3rek,3rel,3tu4,3ut9,3uta,3utb,3w96,3w97,3w98,3w99,3wa9,3waa,3wkj,3wtp,3x1s,3x1t,3x1u,3x1v,4j8u,4j8v,4j8w,4j8x,4jjn,4kgc,4kud,4ld9,4qlc,4r8p,4wu8,4wu9,4x23,4xuj,4xzq,4ym5,4ym6,4ys3,4z5t,4z66,4zux,5av5,5av6,5av8,5av9,5avb,5avc,5ay8,5b0y,5b0z,5b1l,5b1m,5b24,5b2i,5b2j,5b31,5b32,5b33,5b40,5cp6,5cpi,5cpj,5cpk,5dnm,5dnn,5e5a,5f99,5gse,5gsu,5gt0,5gt3,5gtc,5gxq,5hq2,5jrg,5kgf,5mlu,5nl0,5o9g,5omx,5ong,5onw,5oxv,5oy7,5x0x,5x0y,5x7x,5xf3,5xf4,5xf5,5xf6,5xm0,5xm1,6buz,6c0w,6esf,6esg,6esh,6esi,6etx,6fml,6fq5,6fq6,6fq8'.split(',')

    for pair in sumDict:
        chains = pair.split('@')
        target = chains[0]
        source = chains[1]
        
        contacts = sumDict[pair][0]
        pdbIDs = ''
        
        for pdb in sumDict[pair][1]:
            pdbIDs += pdb + '#'

        targetFields = target.split('#')
        sourceFields = source.split('#')
        
        smallList = pdbIDs.split('#')
        
        intersectionFlag = 0
        
        for sPDB in smallList:
            
            if(sPDB in pdbList):
                intersectionFlag = 1
                break
        
        if(len(targetFields) > 1 and intersectionFlag):
            print(source + '\t' + target + '\t' + pdbIDs + '\t' + 'nucleosome')
            
        elif(len(sourceFields) > 1 and intersectionFlag):
            print(target + '\t' + source + '\t' + pdbIDs + '\t' + 'nucleosome')
            
        elif(intersectionFlag):
            print(target + '\t' + source + '\t' + pdbIDs + '\t' + 'nucleosome')
            
        else:
            print(target + '\t' + source + '\t' + pdbIDs + '\t' + 'histone')
            
        #print(target + '\t' + source + '\t' + str(contacts))

# %%
if __name__ == "__main__":
    main()
# Out:
# 1aoi	nucleosome	no bp
# 					1e6i	histone	Q03330#Histone acetyltransferase GCN5
# 1e6i	histone	yes bp
# 1eqz	nucleosome	no bp
# 1f66	nucleosome	no bp
# 					1guw	histone	P83917#Chromobox protein homolog 1
# 1guw	histone	yes bp
# 1hio	nucleosome	no bp
# 1hq3	nucleosome	no bp
# 1hst	histone	no bp
# 1id3	nucleosome	no bp
# 					1kna	histone	P05205#Heterochromatin protein 1
# 1kna	histone	yes bp
# 					1kne	histone	P05205#Heterochromatin protein 1
# 1kne	histone	yes bp
# 1ku5	histone	no bp
# 1kx3	nucleosome	no bp
# 1kx4	nucleosome	no bp
# 1kx5	nucleosome	no bp
# 1m18	nucleosome	no bp
# 1m19	nucleosome	no bp
# 1m1a	nucleosome	no bp
# 					1m1d	histone	Q27198#NA
# 1m1d	histone	yes bp
# 					1o9s	histone	Q8WTS6#Histone-lysine N-methyltransferase SETD7
# 1o9s	histone	yes bp
# 1p34	nucleosome	no bp
# 1p3a	nucleosome	no bp
# 1p3b	nucleosome	no bp
# 1p3f	nucleosome	no bp
# 1p3g	nucleosome	no bp
# 1p3i	nucleosome	no bp
# 1p3k	nucleosome	no bp
# 1p3l	nucleosome	no bp
# 1p3m	nucleosome	no bp
# 1p3o	nucleosome	no bp
# 1p3p	nucleosome	no bp
# 					1pdq	histone	P26017#Polycomb group protein Pc
# 1pdq	histone	yes bp
# 					1peg	histone	Q8X225#Histone-lysine N-methyltransferase, H3 lysine-9 specific dim-5
# 1peg	histone	yes bp
# 					1pfb	histone	P26017#Polycomb group protein Pc
# 1pfb	histone	yes bp
# 					1pu9	histone	Q27198#NA
# 1pu9	histone	yes bp
# 					1pua	histone	Q27198#NA
# 1pua	histone	yes bp
# 					1q1a	histone	P53686#NAD-dependent protein deacetylase HST2
# 1q1a	histone	yes bp
# 					1q2c	histone	Q27198#NA
# 1q2c	histone	yes bp
# 					1q3l	histone	P05205#Heterochromatin protein 1
# 1q3l	histone	yes bp
# 					1qsn	histone	Q27198#NA
# 1qsn	histone	yes bp
# 1s32	nucleosome	no bp
# 					1s5p	histone	P75960#NAD-dependent protein deacylase
# 1s5p	histone	yes bp
# 					1szc	histone	P53686#NAD-dependent protein deacetylase HST2
# 1szc	histone	yes bp
# 					1szd	histone	P53686#NAD-dependent protein deacetylase HST2
# 1szd	histone	yes bp
# 1tzy	nucleosome	no bp
# 1u35	nucleosome	no bp
# 1uss	histone	no bp
# 1ust	histone	no bp
# 1yd9	histone	no bp
# 					1ydp	histone	P61769#Beta-2-microglobulin
# 1ydp	histone	yes bp
# 1zbb	nucleosome	no bp
# 					1zkk	histone	Q9NQR1#N-lysine methyltransferase KMT5A
# 1zkk	histone	yes bp
# 					1zla	nucleosome	Q9DUM3#NA
# 1zla	nucleosome	yes bp
# 1zr3	histone	no bp
# 1zr5	histone	no bp
# 2aro	nucleosome	no bp
# 					2azm	histone	Q14676#Mediator of DNA damage checkpoint protein 1
# 2azm	histone	yes bp
# 					2b2t	histone	O14646#Chromodomain-helicase-DNA-binding protein 1
# 2b2t	histone	yes bp
# 					2b2u	histone	O14646#Chromodomain-helicase-DNA-binding protein 1
# 2b2u	histone	yes bp
# 					2b2v	histone	O14646#Chromodomain-helicase-DNA-binding protein 1
# 2b2v	histone	yes bp
# 					2b2w	histone	O14646#Chromodomain-helicase-DNA-binding protein 1
# 2b2w	histone	yes bp
# 					2c1j	histone	P63104#14-3-3 protein zeta/delta
# 2c1j	histone	yes bp
# 					2c1n	histone	P63104#14-3-3 protein zeta/delta
# 2c1n	histone	yes bp
# 					2cnx	histone	P61964#WD repeat-containing protein 5
# 2cnx	histone	yes bp
# 					2co0	histone	P61964#WD repeat-containing protein 5
# 2co0	histone	yes bp
# 2cv5	nucleosome	no bp
# 					2d31	histone	P61769#Beta-2-microglobulin
# 2d31	histone	yes bp
# 					2dew	histone	Q9UM07#Protein-arginine deiminase type-4
# 2dew	histone	yes bp
# 					2dex	histone	Q9UM07#Protein-arginine deiminase type-4
# 2dex	histone	yes bp
# 					2dey	histone	Q9UM07#Protein-arginine deiminase type-4
# 2dey	histone	yes bp
# 					2dvq	histone	P25440#Bromodomain-containing protein 2
# 2dvq	histone	yes bp
# 					2dvr	histone	P25440#Bromodomain-containing protein 2
# 2dvr	histone	yes bp
# 					2dvs	histone	P25440#Bromodomain-containing protein 2
# 2dvs	histone	yes bp
# 					2dyp	histone	P61769#Beta-2-microglobulin
# 2dyp	histone	yes bp
# 					2dze	histone	O74515#Histone chaperone cia1
# 2dze	histone	yes bp
# 					2e3k	histone	P25440#Bromodomain-containing protein 2
# 2e3k	histone	yes bp
# 					2f6j	histone	Q12830#Nucleosome-remodeling factor subunit BPTF
# 2f6j	histone	yes bp
# 2f8n	nucleosome	no bp
# 2fj7	nucleosome	no bp
# 					2fsa	histone	Q12830#Nucleosome-remodeling factor subunit BPTF
# 2fsa	histone	yes bp
# 2fxk	histone	no bp
# 					2g6q	histone	Q9ESK4#Inhibitor of growth protein 2
# 2g6q	histone	yes bp
# 					2g99	histone	P61964#WD repeat-containing protein 5
# 2g99	histone	yes bp
# 					2g9a	histone	P61964#WD repeat-containing protein 5
# 2g9a	histone	yes bp
# 					2h13	histone	P61964#WD repeat-containing protein 5
# 2h13	histone	yes bp
# 					2h2g	histone	Q9WYW0#NAD-dependent protein deacetylase
# 2h2g	histone	yes bp
# 					2h2h	histone	Q9WYW0#NAD-dependent protein deacetylase
# 2h2h	histone	yes bp
# 					2h6k	histone	P61964#WD repeat-containing protein 5
# 2h6k	histone	yes bp
# 					2h6n	histone	P61964#WD repeat-containing protein 5
# 2h6n	histone	yes bp
# 					2h6q	histone	P61964#WD repeat-containing protein 5
# 2h6q	histone	yes bp
# 					2h9m	histone	P61964#WD repeat-containing protein 5
# 2h9m	histone	yes bp
# 					2h9n	histone	P61964#WD repeat-containing protein 5
# 2h9n	histone	yes bp
# 					2h9p	histone	P61964#WD repeat-containing protein 5
# 2h9p	histone	yes bp
# 2hio	nucleosome	no bp
# 					2hue	histone	P32447#Histone chaperone ASF1
# 2hue	histone	yes bp
# 					2ig0	histone	Q12888#TP53-binding protein 1
# 2ig0	histone	yes bp
# 					2io5	histone	Q9Y294#Histone chaperone ASF1A
# 2io5	histone	yes bp
# 					2kvm	histone	Q8VDS3#Chromobox protein homolog 7
# 2kvm	histone	yes bp
# 					2kwj	histone	Q92784#Zinc finger protein DPF3
# 2kwj	histone	yes bp
# 					2kwk	histone	Q92784#Zinc finger protein DPF3
# 2kwk	histone	yes bp
# 					2kwn	histone	Q92784#Zinc finger protein DPF3
# 2kwn	histone	yes bp
# 					2kwo	histone	Q92784#Zinc finger protein DPF3
# 2kwo	histone	yes bp
# 					2l11	histone	Q13185#Chromobox protein homolog 3
# 2l11	histone	yes bp
# 					2l12	histone	O95931#Chromobox protein homolog 7
# 2l12	histone	yes bp
# 					2l1b	histone	O95931#Chromobox protein homolog 7
# 2l1b	histone	yes bp
# 					2l3r	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 2l3r	histone	yes bp
# 2l43	histone	no bp
# 2l5a	histone	no bp
# 					2l75	histone	Q14839#Chromodomain-helicase-DNA-binding protein 4
# 2l75	histone	yes bp
# 					2lbm	histone	P46100#Transcriptional regulator ATRX
# 2lbm	histone	yes bp
# 					2lgg	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 2lgg	histone	yes bp
# 					2lgk	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 2lgk	histone	yes bp
# 2lso	histone	no bp
# 					2lvm	histone	Q12888#TP53-binding protein 1
# 2lvm	histone	yes bp
# 2ly8	histone	no bp
# 					2mnz	histone	Q9UGL1#Lysine-specific demethylase 5B
# 2mnz	histone	yes bp
# 					2ndf	histone	P42568#Protein AF-9
# 2ndf	histone	yes bp
# 					2ndg	histone	P42568#Protein AF-9
# 2ndg	histone	yes bp
# 2nqb	nucleosome	no bp
# 2nzd	nucleosome	no bp
# 					2o9k	histone	P61964#WD repeat-containing protein 5
# 2o9k	histone	yes bp
# 					2od7	histone	P53686#NAD-dependent protein deacetylase HST2
# 2od7	histone	yes bp
# 					2oq6	histone	O75164#Lysine-specific demethylase 4A
# 2oq6	histone	yes bp
# 					2os2	histone	O75164#Lysine-specific demethylase 4A
# 2os2	histone	yes bp
# 					2ot7	histone	O75164#Lysine-specific demethylase 4A
# 2ot7	histone	yes bp
# 					2ox0	histone	O75164#Lysine-specific demethylase 4A
# 2ox0	histone	yes bp
# 					2p0w	histone	O14929#Histone acetyltransferase type B catalytic subunit
# 2p0w	histone	yes bp
# 					2p5b	histone	O75164#Lysine-specific demethylase 4A
# 2p5b	histone	yes bp
# 					2pnx	histone	Q9UNL4#Inhibitor of growth protein 4
# 2pnx	histone	yes bp
# 					2pqw	histone	Q9Y468#Lethal(3)malignant brain tumor-like protein 1
# 2pqw	histone	yes bp
# 					2puy	histone	Q96BD5#PHD finger protein 21A
# 2puy	histone	yes bp
# 					2pvc	histone	Q9UJW3#DNA (cytosine-5)-methyltransferase 3-like
# 2pvc	histone	yes bp
# 					2pxj	histone	O75164#Lysine-specific demethylase 4A
# 2pxj	histone	yes bp
# 2pyo	nucleosome	no bp
# 					2q8c	histone	O75164#Lysine-specific demethylase 4A
# 2q8c	histone	yes bp
# 					2q8d	histone	O75164#Lysine-specific demethylase 4A
# 2q8d	histone	yes bp
# 					2q8e	histone	O75164#Lysine-specific demethylase 4A
# 2q8e	histone	yes bp
# 					2qic	histone	Q9UK53#Inhibitor of growth protein 1
# 2qic	histone	yes bp
# 					2qqf	histone	P53686#NAD-dependent protein deacetylase HST2
# 2qqf	histone	yes bp
# 					2qqg	histone	P53686#NAD-dependent protein deacetylase HST2
# 2qqg	histone	yes bp
# 					2qqs	histone	O75164#Lysine-specific demethylase 4A
# 2qqs	histone	yes bp
# 					2r0y	histone	Q02206#Chromatin structure-remodeling complex subunit RSC4
# 2r0y	histone	yes bp
# 					2rfi	histone	Q9H9B1#Histone-lysine N-methyltransferase EHMT1
# 2rfi	histone	yes bp
# 					2rhi	histone	Q9Y468#Lethal(3)malignant brain tumor-like protein 1
# 2rhi	histone	yes bp
# 					2ri7	histone	Q12830#Nucleosome-remodeling factor subunit BPTF
# 2ri7	histone	yes bp
# 					2rje	histone	Q9Y468#Lethal(3)malignant brain tumor-like protein 1
# 2rje	histone	yes bp
# 					2rjf	histone	Q9Y468#Lethal(3)malignant brain tumor-like protein 1
# 2rjf	histone	yes bp
# 					2rr4	histone	Q9H0M4#Zinc finger CW-type PWWP domain protein 1
# 2rr4	histone	yes bp
# 					2rs9	histone	P55201#Peregrin
# 2rs9	histone	yes bp
# 					2rsn	histone	Q10103#Chromo domain-containing protein 1
# 2rsn	histone	yes bp
# 					2rvn	histone	Q61686#Chromobox protein homolog 5
# 2rvn	histone	yes bp
# 2rvq	histone	no bp
# 					2uxn	histone	O60341#Lysine-specific histone demethylase 1A
# 2uxn	histone	yes bp
# 					2v1d	histone	O60341#Lysine-specific histone demethylase 1A
# 2v1d	histone	yes bp
# 					2v83	histone	P21784#V(D)J recombination-activating protein 2
# 2v83	histone	yes bp
# 					2v85	histone	P21784#V(D)J recombination-activating protein 2
# 2v85	histone	yes bp
# 					2v86	histone	P21784#V(D)J recombination-activating protein 2
# 2v86	histone	yes bp
# 					2v87	histone	P21784#V(D)J recombination-activating protein 2
# 2v87	histone	yes bp
# 					2v88	histone	P21784#V(D)J recombination-activating protein 2
# 2v88	histone	yes bp
# 					2v89	histone	P21784#V(D)J recombination-activating protein 2
# 2v89	histone	yes bp
# 					2vnf	histone	Q9UNL4#Inhibitor of growth protein 4
# 2vnf	histone	yes bp
# 					2vpe	histone	O00512#B-cell CLL/lymphoma 9 protein
# 2vpe	histone	yes bp
# 					2vpg	histone	O00512#B-cell CLL/lymphoma 9 protein
# 2vpg	histone	yes bp
# 					2w5z	histone	Q03164#Histone-lysine N-methyltransferase 2A
# 2w5z	histone	yes bp
# 					2wp1	histone	Q91Y44#Bromodomain testis-specific protein
# 2wp1	histone	yes bp
# 					2wp2	histone	Q91Y44#Bromodomain testis-specific protein
# 2wp2	histone	yes bp
# 					2x0l	histone	O60341#Lysine-specific histone demethylase 1A
# 2x0l	histone	yes bp
# 					2x4w	histone	P55201#Peregrin
# 2x4w	histone	yes bp
# 					2x4x	histone	P55201#Peregrin
# 2x4x	histone	yes bp
# 					2x4y	histone	P55201#Peregrin
# 2x4y	histone	yes bp
# 2xd7	histone	no bp
# 					2xl3	histone	Q8BX09#Retinoblastoma-binding protein 5
# 2xl3	histone	yes bp
# 2xql	histone	no bp
# 					2xyi	histone	Q24572#Probable histone-binding protein Caf1
# 2xyi	histone	yes bp
# 					2yba	histone	Q24572#Probable histone-binding protein Caf1
# 2yba	histone	yes bp
# 					2ybp	histone	O75164#Lysine-specific demethylase 4A
# 2ybp	histone	yes bp
# 					2ybs	histone	O75164#Lysine-specific demethylase 4A
# 2ybs	histone	yes bp
# 					2yfv	histone	Q6CL77#SCM3
# 2yfv	histone	yes bp
# 2yfw	histone	no bp
# 					2yyr	histone	Q9D0P5#Pygopus homolog 1
# 2yyr	histone	yes bp
# 3a6n	nucleosome	no bp
# 3afa	nucleosome	no bp
# 3an2	nucleosome	no bp
# 					3ask	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3ask	histone	yes bp
# 					3asl	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3asl	histone	yes bp
# 3av1	nucleosome	no bp
# 3av2	nucleosome	no bp
# 					3avr	histone	O15550#Lysine-specific demethylase 6A
# 3avr	histone	yes bp
# 3ayw	nucleosome	no bp
# 3aze	nucleosome	no bp
# 3azf	nucleosome	no bp
# 3azg	nucleosome	no bp
# 3azh	nucleosome	no bp
# 3azi	nucleosome	no bp
# 3azj	nucleosome	no bp
# 3azk	nucleosome	no bp
# 3azl	nucleosome	no bp
# 3azm	nucleosome	no bp
# 3azn	nucleosome	no bp
# 3b6f	nucleosome	no bp
# 3b6g	nucleosome	no bp
# 					3b95	histone	Q9H9B1#Histone-lysine N-methyltransferase EHMT1
# 3b95	histone	yes bp
# 3c1b	nucleosome	no bp
# 3c1c	nucleosome	no bp
# 					3c6w	histone	Q8WYH8#Inhibitor of growth protein 5
# 3c6w	histone	yes bp
# 					3c9c	histone	Q24572#Probable histone-binding protein Caf1
# 3c9c	histone	yes bp
# 					3cfs	histone	Q16576#Histone-binding protein RBBP7
# 3cfs	histone	yes bp
# 					3cfv	histone	Q16576#Histone-binding protein RBBP7
# 3cfv	histone	yes bp
# 					3db3	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3db3	histone	yes bp
# 					3f9w	histone	Q9NQR1#N-lysine methyltransferase KMT5A
# 3f9w	histone	yes bp
# 					3f9x	histone	Q9NQR1#N-lysine methyltransferase KMT5A
# 3f9x	histone	yes bp
# 					3f9y	histone	Q9NQR1#N-lysine methyltransferase KMT5A
# 3f9y	histone	yes bp
# 					3f9z	histone	Q9NQR1#N-lysine methyltransferase KMT5A
# 3f9z	histone	yes bp
# 					3fdt	histone	P45973#Chromobox protein homolog 5
# 3fdt	histone	yes bp
# 					3g7l	histone	Q10103#Chromo domain-containing protein 1
# 3g7l	histone	yes bp
# 					3gl6	histone	P29375#Lysine-specific demethylase 5A
# 3gl6	histone	yes bp
# 					3gv6	histone	O95503#Chromobox protein homolog 6
# 3gv6	histone	yes bp
# 					3hna	histone	Q9H9B1#Histone-lysine N-methyltransferase EHMT1
# 3hna	histone	yes bp
# 					3hsv	histone	Q5NVK7#Speckle-type POZ protein
# 3hsv	histone	yes bp
# 3iid	histone	no bp
# 3iif	histone	no bp
# 					3iiw	histone	O75530#Polycomb protein EED
# 3iiw	histone	yes bp
# 					3iiy	histone	O75530#Polycomb protein EED
# 3iiy	histone	yes bp
# 					3ij0	histone	O75530#Polycomb protein EED
# 3ij0	histone	yes bp
# 					3ij1	histone	O75530#Polycomb protein EED
# 3ij1	histone	yes bp
# 					3ivb	histone	O43791#Speckle-type POZ protein
# 3ivb	histone	yes bp
# 					3jpx	histone	O75530#Polycomb protein EED
# 3jpx	histone	yes bp
# 					3jvk	histone	Q9ESU6#Bromodomain-containing protein 4
# 3jvk	histone	yes bp
# 					3jzg	histone	O75530#Polycomb protein EED
# 3jzg	histone	yes bp
# 					3jzh	histone	O75530#Polycomb protein EED
# 3jzh	histone	yes bp
# 					3k24	histone	P07711#Cathepsin L1
# 3k24	histone	yes bp
# 					3k26	histone	O75530#Polycomb protein EED
# 3k26	histone	yes bp
# 					3k27	histone	O75530#Polycomb protein EED
# 3k27	histone	yes bp
# 					3kmt	histone	O41094#A612L protein
# 3kmt	histone	yes bp
# 					3kqi	histone	O75151#Lysine-specific demethylase PHF2
# 3kqi	histone	yes bp
# 3kuy	nucleosome	no bp
# 					3kv4	histone	Q9UPP1#Histone lysine demethylase PHF8
# 3kv4	histone	yes bp
# 3kwq	nucleosome	no bp
# 3kxb	nucleosome	no bp
# 3lel	nucleosome	no bp
# 3lja	nucleosome	no bp
# 					3lqi	histone	Q03164#Histone-lysine N-methyltransferase 2A
# 3lqi	histone	yes bp
# 					3lqj	histone	Q03164#Histone-lysine N-methyltransferase 2A
# 3lqj	histone	yes bp
# 3lz0	nucleosome	no bp
# 3lz1	nucleosome	no bp
# 					3me9	histone	Q96ES7#SAGA-associated factor 29
# 3me9	histone	yes bp
# 					3mea	histone	Q96ES7#SAGA-associated factor 29
# 3mea	histone	yes bp
# 					3met	histone	Q96ES7#SAGA-associated factor 29
# 3met	histone	yes bp
# 					3meu	histone	Q96ES7#SAGA-associated factor 29
# 3meu	histone	yes bp
# 					3mev	histone	Q96ES7#SAGA-associated factor 29
# 3mev	histone	yes bp
# 3mgp	nucleosome	no bp
# 3mgq	nucleosome	no bp
# 3mgr	nucleosome	no bp
# 3mgs	nucleosome	no bp
# 3mnn	nucleosome	no bp
# 					3mo8	histone	P55201#Peregrin
# 3mo8	histone	yes bp
# 					3mp1	histone	P0AEX9, P25554#P0AEX9:, Maltose-binding periplasmic protein, P25554:, SAGA-associated factor 29
# 3mp1	histone	yes bp
# 					3mp6	histone	P0AEX9, P25554#P0AEX9:, Maltose-binding periplasmic protein, P25554:, SAGA-associated factor 29
# 3mp6	histone	yes bp
# 					3muk	histone	Q9ESU6#Bromodomain-containing protein 4
# 3muk	histone	yes bp
# 					3mul	histone	Q9ESU6#Bromodomain-containing protein 4
# 3mul	histone	yes bp
# 					3mvd	nucleosome	P25171#Regulator of chromosome condensation
# 3mvd	nucleosome	yes bp
# 					3n9l	histone	Q9GYI0#Lysine-specific demethylase 7 homolog
# 3n9l	histone	yes bp
# 					3n9n	histone	Q9GYI0#Lysine-specific demethylase 7 homolog
# 3n9n	histone	yes bp
# 					3n9o	histone	Q9GYI0#Lysine-specific demethylase 7 homolog
# 3n9o	histone	yes bp
# 					3n9p	histone	Q9GYI0#Lysine-specific demethylase 7 homolog
# 3n9p	histone	yes bp
# 					3n9q	histone	Q9GYI0#Lysine-specific demethylase 7 homolog
# 3n9q	histone	yes bp
# 3nqj	histone	no bp
# 3nqu	histone	no bp
# 					3o34	histone	O15164#Transcription intermediary factor 1-alpha
# 3o34	histone	yes bp
# 					3o35	histone	O15164#Transcription intermediary factor 1-alpha
# 3o35	histone	yes bp
# 					3o36	histone	O15164#Transcription intermediary factor 1-alpha
# 3o36	histone	yes bp
# 					3o37	histone	O15164#Transcription intermediary factor 1-alpha
# 3o37	histone	yes bp
# 3o62	nucleosome	no bp
# 					3o7a	histone	Q86YI8#PHD finger protein 13
# 3o7a	histone	yes bp
# 					3oa6	histone	Q8N5Y2#Male-specific lethal 3 homolog
# 3oa6	histone	yes bp
# 					3psl	histone	P61964#WD repeat-containing protein 5
# 3psl	histone	yes bp
# 					3q33	histone	Q07794#Histone acetyltransferase RTT109
# 3q33	histone	yes bp
# 					3qby	histone	Q7Z4V5#Hepatoma-derived growth factor-related protein 2
# 3qby	histone	yes bp
# 					3qj6	histone	Q7Z4V5#Hepatoma-derived growth factor-related protein 2
# 3qj6	histone	yes bp
# 					3ql9	histone	P46100#Transcriptional regulator ATRX
# 3ql9	histone	yes bp
# 					3qla	histone	P46100#Transcriptional regulator ATRX
# 3qla	histone	yes bp
# 					3qlc	histone	P46100#Transcriptional regulator ATRX
# 3qlc	histone	yes bp
# 					3qo2	histone	Q99549#M-phase phosphoprotein 8
# 3qo2	histone	yes bp
# 					3qzs	histone	Q12830#Nucleosome-remodeling factor subunit BPTF
# 3qzs	histone	yes bp
# 					3qzt	histone	Q12830#Nucleosome-remodeling factor subunit BPTF
# 3qzt	histone	yes bp
# 					3qzv	histone	Q12830#Nucleosome-remodeling factor subunit BPTF
# 3qzv	histone	yes bp
# 					3r45	histone	Q8NCD3#Holliday junction recognition protein
# 3r45	histone	yes bp
# 					3r93	histone	Q99549#M-phase phosphoprotein 8
# 3r93	histone	yes bp
# 3reh	nucleosome	no bp
# 3rei	nucleosome	no bp
# 3rej	nucleosome	no bp
# 3rek	nucleosome	no bp
# 3rel	nucleosome	no bp
# 					3rig	histone	Q9NXA8#NAD-dependent protein deacylase sirtuin-5, mitochondrial
# 3rig	histone	yes bp
# 					3riy	histone	Q9NXA8#NAD-dependent protein deacylase sirtuin-5, mitochondrial
# 3riy	histone	yes bp
# 					3shb	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3shb	histone	yes bp
# 					3shv	histone	Q8NEM0#Microcephalin
# 3shv	histone	yes bp
# 					3sou	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3sou	histone	yes bp
# 					3sow	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3sow	histone	yes bp
# 					3sqd	histone	Q6ZW49#PAX-interacting protein 1
# 3sqd	histone	yes bp
# 					3szm	histone	Q8NEM0#Microcephalin
# 3szm	histone	yes bp
# 					3t6r	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3t6r	histone	yes bp
# 					3t7k	histone	P38850#Regulator of Ty1 transposition protein 107
# 3t7k	histone	yes bp
# 					3to6	histone	Q08649#Histone acetyltransferase ESA1
# 3to6	histone	yes bp
# 					3tu4	nucleosome	P06701#Regulatory protein SIR3
# 3tu4	nucleosome	yes bp
# 					3tzd	histone	Q13185#Chromobox protein homolog 3
# 3tzd	histone	yes bp
# 					3u31	histone	Q8IE47#NAD-dependent protein deacylase Sir2A
# 3u31	histone	yes bp
# 					3u3d	histone	Q8IE47#NAD-dependent protein deacylase Sir2A
# 3u3d	histone	yes bp
# 					3u3z	histone	Q8NEM0#Microcephalin
# 3u3z	histone	yes bp
# 					3u4s	histone	O75164#Lysine-specific demethylase 4A
# 3u4s	histone	yes bp
# 					3u5n	histone	Q9UPN9#E3 ubiquitin-protein ligase TRIM33
# 3u5n	histone	yes bp
# 					3u5o	histone	Q9UPN9#E3 ubiquitin-protein ligase TRIM33
# 3u5o	histone	yes bp
# 					3u5p	histone	Q9UPN9#E3 ubiquitin-protein ligase TRIM33
# 3u5p	histone	yes bp
# 					3uec	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 3uec	histone	yes bp
# 					3ued	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 3ued	histone	yes bp
# 					3uee	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 3uee	histone	yes bp
# 					3uef	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 3uef	histone	yes bp
# 					3uii	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 3uii	histone	yes bp
# 					3uik	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 3uik	histone	yes bp
# 3ut9	nucleosome	no bp
# 3uta	nucleosome	no bp
# 3utb	nucleosome	no bp
# 					3uvw	histone	O60885#Bromodomain-containing protein 4
# 3uvw	histone	yes bp
# 					3uvx	histone	O60885#Bromodomain-containing protein 4
# 3uvx	histone	yes bp
# 					3uvy	histone	O60885#Bromodomain-containing protein 4
# 3uvy	histone	yes bp
# 					3uw9	histone	O60885#Bromodomain-containing protein 4
# 3uw9	histone	yes bp
# 					3v43	histone	Q92794#Histone acetyltransferase KAT6A
# 3v43	histone	yes bp
# 3w96	nucleosome	no bp
# 3w97	nucleosome	no bp
# 3w98	nucleosome	no bp
# 3w99	nucleosome	no bp
# 3wa9	nucleosome	no bp
# 3waa	nucleosome	no bp
# 3wkj	nucleosome	no bp
# 3wtp	nucleosome	no bp
# 3x1s	nucleosome	no bp
# 3x1t	nucleosome	no bp
# 3x1u	nucleosome	no bp
# 3x1v	nucleosome	no bp
# 					3zvy	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 3zvy	histone	yes bp
# 					4a0j	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 4a0j	histone	yes bp
# 					4a0n	histone	O15392#Baculoviral IAP repeat-containing protein 5
# 4a0n	histone	yes bp
# 					4a7j	histone	P61964#WD repeat-containing protein 5
# 4a7j	histone	yes bp
# 					4au7	histone	Q6Q783#Histone-lysine N-methyltransferase KMT5C
# 4au7	histone	yes bp
# 					4bd3	histone	Q5T6S3#PHD finger protein 19
# 4bd3	histone	yes bp
# 					4c1q	histone	Q96EQ9#Histone-lysine N-methyltransferase PRDM9
# 4c1q	histone	yes bp
# 					4cay	histone	Q9BTT0#Acidic leucine-rich nuclear phosphoprotein 32 family member E
# 4cay	histone	yes bp
# 					4dow	histone	Q9Z1N2#Origin recognition complex subunit 1
# 4dow	histone	yes bp
# 					4edu	histone	Q9UQR0#Sex comb on midleg-like protein 2
# 4edu	histone	yes bp
# 					4eo5	histone	P32447#Histone chaperone ASF1
# 4eo5	histone	yes bp
# 					4ezh	histone	Q5NCY0#Lysine-specific demethylase 6B
# 4ezh	histone	yes bp
# 					4f4u	histone	Q9NXA8#NAD-dependent protein deacylase sirtuin-5, mitochondrial
# 4f4u	histone	yes bp
# 					4f56	histone	Q9NXA8#NAD-dependent protein deacylase sirtuin-5, mitochondrial
# 4f56	histone	yes bp
# 					4ft2	histone	Q9AXT8#DNA (cytosine-5)-methyltransferase 1
# 4ft2	histone	yes bp
# 					4ft4	histone	Q9AXT8#DNA (cytosine-5)-methyltransferase 1
# 4ft4	histone	yes bp
# 					4fwf	histone	Q8NB78#Lysine-specific histone demethylase 1B
# 4fwf	histone	yes bp
# 					4gne	histone	Q9BZ95#Histone-lysine N-methyltransferase NSD3
# 4gne	histone	yes bp
# 					4gnf	histone	Q9BZ95#Histone-lysine N-methyltransferase NSD3
# 4gnf	histone	yes bp
# 					4gng	histone	Q9BZ95#Histone-lysine N-methyltransferase NSD3
# 4gng	histone	yes bp
# 					4gqb	histone	Q9BQA1#Methylosome protein 50
# 4gqb	histone	yes bp
# 					4gu0	histone	Q8NB78#Lysine-specific histone demethylase 1B
# 4gu0	histone	yes bp
# 					4gur	histone	Q8NB78#Lysine-specific histone demethylase 1B
# 4gur	histone	yes bp
# 					4gus	histone	Q8NB78#Lysine-specific histone demethylase 1B
# 4gus	histone	yes bp
# 					4gy5	histone	Q96T88#E3 ubiquitin-protein ligase UHRF1
# 4gy5	histone	yes bp
# 					4h75	histone	Q9Y657#Spindlin-1
# 4h75	histone	yes bp
# 					4h9n	histone	Q9UER7#Death domain-associated protein 6
# 4h9n	histone	yes bp
# 					4h9o	histone	Q9UER7#Death domain-associated protein 6
# 4h9o	histone	yes bp
# 					4h9p	histone	Q9UER7#Death domain-associated protein 6
# 4h9p	histone	yes bp
# 					4h9q	histone	Q9UER7#Death domain-associated protein 6
# 4h9q	histone	yes bp
# 					4h9r	histone	Q9UER7#Death domain-associated protein 6
# 4h9r	histone	yes bp
# 					4h9s	histone	Q9UER7#Death domain-associated protein 6
# 4h9s	histone	yes bp
# 					4hcz	histone	O43189#PHD finger protein 1
# 4hcz	histone	yes bp
# 					4hga	histone	Q9UER7#Death domain-associated protein 6
# 4hga	histone	yes bp
# 					4hon	histone	Q6B0I6#Lysine-specific demethylase 4D
# 4hon	histone	yes bp
# 					4hsu	histone	Q8NB78#Lysine-specific histone demethylase 1B
# 4hsu	histone	yes bp
# 					4i51	histone	Q9H9B1#Histone-lysine N-methyltransferase EHMT1
# 4i51	histone	yes bp
# 					4iur	histone	Q9XI47#Protein SAWADEE HOMEODOMAIN HOMOLOG 1
# 4iur	histone	yes bp
# 					4iut	histone	Q9XI47#Protein SAWADEE HOMEODOMAIN HOMOLOG 1
# 4iut	histone	yes bp
# 					4iuu	histone	Q9XI47#Protein SAWADEE HOMEODOMAIN HOMOLOG 1
# 4iuu	histone	yes bp
# 					4iuv	histone	Q9XI47#Protein SAWADEE HOMEODOMAIN HOMOLOG 1
# 4iuv	histone	yes bp
# 4j8u	nucleosome	no bp
# 4j8v	nucleosome	no bp
# 4j8w	nucleosome	no bp
# 4j8x	nucleosome	no bp
# 					4jjn	nucleosome	P06701#Regulatory protein SIR3
# 4jjn	nucleosome	yes bp
# 4kgc	nucleosome	no bp
# 4kha	histone	no bp
# 					4kud	nucleosome	P06701#Regulatory protein SIR3
# 4kud	nucleosome	yes bp
# 					4l58	histone	Q8IZD2#Inactive histone-lysine N-methyltransferase 2E
# 4l58	histone	yes bp
# 					4l7x	histone	Q9BTC0#Death-inducer obliterator 1
# 4l7x	histone	yes bp
# 					4ld9	nucleosome	P06701#Regulatory protein SIR3
# 4ld9	nucleosome	yes bp
# 					4lk9	histone	Q92794#Histone acetyltransferase KAT6A
# 4lk9	histone	yes bp
# 					4lka	histone	Q92794#Histone acetyltransferase KAT6A
# 4lka	histone	yes bp
# 					4llb	histone	Q92794#Histone acetyltransferase KAT6A
# 4llb	histone	yes bp
# 					4lxl	histone	O94953#Lysine-specific demethylase 4B
# 4lxl	histone	yes bp
# 					4m38	histone	Q582G4#Protein arginine N-methyltransferase 7
# 4m38	histone	yes bp
# 					4m6b	histone	Q05471#Helicase SWR1
# 4m6b	histone	yes bp
# 					4mzf	histone	Q9Y657#Spindlin-1
# 4mzf	histone	yes bp
# 					4mzg	histone	Q9Y657#Spindlin-1
# 4mzg	histone	yes bp
# 					4mzh	histone	Q9Y657#Spindlin-1
# 4mzh	histone	yes bp
# 					4n3w	histone	Q92793#CREB-binding protein
# 4n3w	histone	yes bp
# 					4n4f	histone	Q92793#CREB-binding protein
# 4n4f	histone	yes bp
# 					4n4h	histone	Q8R5C8#Zinc finger MYND domain-containing protein 11
# 4n4h	histone	yes bp
# 					4n4i	histone	Q8R5C8#Zinc finger MYND domain-containing protein 11
# 4n4i	histone	yes bp
# 4nft	histone	no bp
# 					4o30	histone	B9RU15#Probable Histone-lysine N-methyltransferase ATXR5
# 4o30	histone	yes bp
# 					4o62	histone	Q504Y3#Zinc finger CW-type PWWP domain protein 2
# 4o62	histone	yes bp
# 					4ouc	histone	Q8TF76#Serine/threonine-protein kinase haspin
# 4ouc	histone	yes bp
# 					4pl6	histone	Q4V3E2#Protein MRG2
# 4pl6	histone	yes bp
# 					4pli	histone	Q4V3E2#Protein MRG2
# 4pli	histone	yes bp
# 					4pll	histone	Q4V3E2#Protein MRG2
# 4pll	histone	yes bp
# 					4psw	histone	Q12341#Histone acetyltransferase type B catalytic subunit
# 4psw	histone	yes bp
# 					4psx	histone	Q12341#Histone acetyltransferase type B catalytic subunit
# 4psx	histone	yes bp
# 					4q6f	histone	Q9UIF9#Bromodomain adjacent to zinc finger domain protein 2A
# 4q6f	histone	yes bp
# 					4qbm	histone	Q9UIF9#Bromodomain adjacent to zinc finger domain protein 2A
# 4qbm	histone	yes bp
# 					4qbq	histone	Q9Y6K1#DNA (cytosine-5)-methyltransferase 3A
# 4qbq	histone	yes bp
# 					4qbr	histone	Q9Y6K1#DNA (cytosine-5)-methyltransferase 3A
# 4qbr	histone	yes bp
# 					4qbs	histone	Q9Y6K1#DNA (cytosine-5)-methyltransferase 3A
# 4qbs	histone	yes bp
# 					4qc1	histone	Q9UIF8#Bromodomain adjacent to zinc finger domain protein 2B
# 4qc1	histone	yes bp
# 					4qc3	histone	Q9UIF8#Bromodomain adjacent to zinc finger domain protein 2B
# 4qc3	histone	yes bp
# 					4qeo	histone	Q8GZB6#Histone-lysine N-methyltransferase, H3 lysine-9 specific SUVH4
# 4qeo	histone	yes bp
# 4qlc	nucleosome	no bp
# 					4qq4	histone	Q14149#MORC family CW-type zinc finger protein 3
# 4qq4	histone	yes bp
# 					4quf	histone	Q7JXA8#RE36324p
# 4quf	histone	yes bp
# 					4qut	histone	Q6PL18#ATPase family AAA domain-containing protein 2
# 4qut	histone	yes bp
# 					4quu	histone	Q6PL18#ATPase family AAA domain-containing protein 2
# 4quu	histone	yes bp
# 					4qwn	histone	P59997#Lysine-specific demethylase 2A
# 4qwn	histone	yes bp
# 					4qx7	histone	P59997#Lysine-specific demethylase 2A
# 4qx7	histone	yes bp
# 					4qx8	histone	P59997#Lysine-specific demethylase 2A
# 4qx8	histone	yes bp
# 					4qxb	histone	P59997#Lysine-specific demethylase 2A
# 4qxb	histone	yes bp
# 					4qxc	histone	P59997#Lysine-specific demethylase 2A
# 4qxc	histone	yes bp
# 					4qxh	histone	P59997#Lysine-specific demethylase 2A
# 4qxh	histone	yes bp
# 					4qyd	histone	P55201#Peregrin
# 4qyd	histone	yes bp
# 					4qyl	histone	P55201#Peregrin
# 4qyl	histone	yes bp
# 					4r8p	nucleosome	P61077, Q99496#P61077:, Ubiquitin-conjugating enzyme E2 D3, Q99496:, E3 ubiquitin-protein ligase RING2
# 4r8p	nucleosome	yes bp
# 					4tmp	histone	P42568#Protein AF-9
# 4tmp	histone	yes bp
# 					4tn7	histone	P59997#Lysine-specific demethylase 2A
# 4tn7	histone	yes bp
# 					4tt2	histone	Q6PL18#ATPase family AAA domain-containing protein 2
# 4tt2	histone	yes bp
# 					4tt4	histone	Q6PL18#ATPase family AAA domain-containing protein 2
# 4tt4	histone	yes bp
# 					4twi	histone	O28597#NAD-dependent protein deacylase 1
# 4twi	histone	yes bp
# 					4twj	histone	O30124#NAD-dependent protein deacylase 2
# 4twj	histone	yes bp
# 					4u68	histone	Q7JXA8#Rhino
# 4u68	histone	yes bp
# 					4u7t	histone	Q9UJW3#DNA (cytosine-5)-methyltransferase 3-like
# 4u7t	histone	yes bp
# 					4u9w	histone	Q86UY6#N-alpha-acetyltransferase 40
# 4u9w	histone	yes bp
# 					4up0	histone	Q86UU0, Q9BRQ0#Q86UU0:, B-cell CLL/lymphoma 9-like protein, Q9BRQ0:, Pygopus homolog 2
# 4up0	histone	yes bp
# 					4uuz	histone	P49736#DNA replication licensing factor MCM2
# 4uuz	histone	yes bp
# 					4uy4	histone	Q56A73#Spindlin-4
# 4uy4	histone	yes bp
# 					4v2v	histone	O75164#Lysine-specific demethylase 4A
# 4v2v	histone	yes bp
# 					4v2w	histone	O75164#Lysine-specific demethylase 4A
# 4v2w	histone	yes bp
# 					4w5a	histone	P46100#Transcriptional regulator ATRX
# 4w5a	histone	yes bp
# 4wnn	histone	no bp
# 4wu8	nucleosome	no bp
# 4wu9	nucleosome	no bp
# 					4x23	nucleosome	Q66LH7#CENP-C
# 4x23	nucleosome	yes bp
# 4xuj	nucleosome	no bp
# 					4xyi	histone	B6K598#Kinetochore protein Mis16
# 4xyi	histone	yes bp
# 4xzq	nucleosome	no bp
# 					4yhp	histone	NA#Fab Heavy Chain
# 4yhp	histone	yes bp
# 					4yhz	histone	NA#Fab Heavy Chain
# 4yhz	histone	yes bp
# 4ym5	nucleosome	no bp
# 4ym6	nucleosome	no bp
# 4ys3	nucleosome	no bp
# 					4yy6	histone	Q9H8M2#Bromodomain-containing protein 9
# 4yy6	histone	yes bp
# 					4yyd	histone	Q9H8M2#Bromodomain-containing protein 9
# 4yyd	histone	yes bp
# 					4yyg	histone	Q9H8M2#Bromodomain-containing protein 9
# 4yyg	histone	yes bp
# 					4yyh	histone	Q9H8M2#Bromodomain-containing protein 9
# 4yyh	histone	yes bp
# 					4yyi	histone	Q9H8M2#Bromodomain-containing protein 9
# 4yyi	histone	yes bp
# 					4yyj	histone	Q9H8M2#Bromodomain-containing protein 9
# 4yyj	histone	yes bp
# 					4yyk	histone	Q9H8M2#Bromodomain-containing protein 9
# 4yyk	histone	yes bp
# 					4yym	histone	P21675#Transcription initiation factor TFIID subunit 1
# 4yym	histone	yes bp
# 					4yyn	histone	P21675#Transcription initiation factor TFIID subunit 1
# 4yyn	histone	yes bp
# 					4z0r	histone	Q504Y3#Zinc finger CW-type PWWP domain protein 2
# 4z0r	histone	yes bp
# 					4z2m	histone	Q9Y5B9#FACT complex subunit SPT16
# 4z2m	histone	yes bp
# 4z5t	nucleosome	no bp
# 4z66	nucleosome	no bp
# 					4zbj	histone	P32447#Histone chaperone ASF1
# 4zbj	histone	yes bp
# 					4zux	nucleosome	P0CG47#Polyubiquitin-B
# 4zux	nucleosome	yes bp
# 5av5	nucleosome	no bp
# 5av6	nucleosome	no bp
# 5av8	nucleosome	no bp
# 5av9	nucleosome	no bp
# 5avb	nucleosome	no bp
# 5avc	nucleosome	no bp
# 5ay8	nucleosome	no bp
# 5b0y	nucleosome	no bp
# 5b0z	nucleosome	no bp
# 5b1l	nucleosome	no bp
# 5b1m	nucleosome	no bp
# 5b24	nucleosome	no bp
# 5b2i	nucleosome	no bp
# 5b2j	nucleosome	no bp
# 5b31	nucleosome	no bp
# 5b32	nucleosome	no bp
# 5b33	nucleosome	no bp
# 5b40	nucleosome	no bp
# 					5b75	histone	Q92794#Histone acetyltransferase KAT6A
# 5b75	histone	yes bp
# 					5b76	histone	Q92794#Histone acetyltransferase KAT6A
# 5b76	histone	yes bp
# 					5b77	histone	Q92794#Histone acetyltransferase KAT6A
# 5b77	histone	yes bp
# 					5b78	histone	Q92794#Histone acetyltransferase KAT6A
# 5b78	histone	yes bp
# 					5bnv	histone	P49736#DNA replication licensing factor MCM2
# 5bnv	histone	yes bp
# 					5bnx	histone	P49736#DNA replication licensing factor MCM2
# 5bnx	histone	yes bp
# 					5bo0	histone	P49736#DNA replication licensing factor MCM2
# 5bo0	histone	yes bp
# 					5bs7	histone	Q68D10#Protein SPT2 homolog
# 5bs7	histone	yes bp
# 					5bsa	histone	Q68D10#Protein SPT2 homolog
# 5bsa	histone	yes bp
# 					5bt1	histone	Q12373#HAT1-interacting factor 1
# 5bt1	histone	yes bp
# 					5c11	histone	P29375#Lysine-specific demethylase 5A
# 5c11	histone	yes bp
# 					5c13	histone	Q5VWG9#Transcription initiation factor TFIID subunit 3
# 5c13	histone	yes bp
# 					5c3i	histone	P49736#DNA replication licensing factor MCM2
# 5c3i	histone	yes bp
# 					5chl	histone	Q9VKM6#Vacuolar protein sorting-associated protein 72 homolog
# 5chl	histone	yes bp
# 					5ciu	histone	Q9UBC3#DNA (cytosine-5)-methyltransferase 3B
# 5ciu	histone	yes bp
# 5cp6	nucleosome	no bp
# 5cpi	nucleosome	no bp
# 5cpj	nucleosome	no bp
# 5cpk	nucleosome	no bp
# 					5cvd	histone	Q9BV86#N-terminal Xaa-Pro-Lys N-methyltransferase 1
# 5cvd	histone	yes bp
# 					5cve	histone	Q9BV86#N-terminal Xaa-Pro-Lys N-methyltransferase 1
# 5cve	histone	yes bp
# 					5d6y	histone	O75164#Lysine-specific demethylase 4A
# 5d6y	histone	yes bp
# 					5d7e	histone	P35189#Transcription initiation factor TFIID subunit 14
# 5d7e	histone	yes bp
# 					5dah	histone	P55197#Protein AF-10
# 5dah	histone	yes bp
# 5dnm	nucleosome	no bp
# 5dnn	nucleosome	no bp
# 					5dwq	histone	Q86X55#Histone-arginine methyltransferase CARM1
# 5dwq	histone	yes bp
# 					5dx0	histone	Q86X55#Histone-arginine methyltransferase CARM1
# 5dx0	histone	yes bp
# 					5e5a	nucleosome	P03169#55 kDa immediate-early protein 1
# 5e5a	nucleosome	yes bp
# 					5efn	histone	F8W4B7#Histone deacetylase
# 5efn	histone	yes bp
# 					5f6k	histone	Q8NEZ4#Histone-lysine N-methyltransferase 2C
# 5f6k	histone	yes bp
# 5f99	nucleosome	no bp
# 					5fa5	histone	Q9BQA1#Methylosome protein 50
# 5fa5	histone	yes bp
# 					5fb0	histone	P23497#Nuclear autoantigen Sp-100
# 5fb0	histone	yes bp
# 					5fb1	histone	P23497#Nuclear autoantigen Sp-100
# 5fb1	histone	yes bp
# 					5ffv	histone	P55201#Peregrin
# 5ffv	histone	yes bp
# 					5ffw	histone	P55201#Peregrin
# 5ffw	histone	yes bp
# 					5fug	histone	Q15906#Vacuolar protein sorting-associated protein 72 homolog
# 5fug	histone	yes bp
# 					5fwe	histone	O75164#Lysine-specific demethylase 4A
# 5fwe	histone	yes bp
# 					5g2e	histone	P25293#Nucleosome assembly protein
# 5g2e	histone	yes bp
# 					5gh9	histone	Q92793#CREB-binding protein
# 5gh9	histone	yes bp
# 5gse	nucleosome	no bp
# 5gsu	nucleosome	no bp
# 5gt0	nucleosome	no bp
# 5gt3	nucleosome	no bp
# 					5gtc	nucleosome	Q9QR71#Protein ORF73
# 5gtc	nucleosome	yes bp
# 5gxq	nucleosome	no bp
# 					5h6q	histone	O60341#Lysine-specific histone demethylase 1A
# 5h6q	histone	yes bp
# 					5h6r	histone	O60341#Lysine-specific histone demethylase 1A
# 5h6r	histone	yes bp
# 					5hh7	histone	Q9SU24#Origin of replication complex subunit 1B
# 5hh7	histone	yes bp
# 					5hjb	histone	P42568#Protein AF-9
# 5hjb	histone	yes bp
# 					5hjc	histone	Q15059#Bromodomain-containing protein 3
# 5hjc	histone	yes bp
# 					5hjd	histone	P42568#Protein AF-9
# 5hjd	histone	yes bp
# 					5hq2	nucleosome	P21827#Guanine nucleotide exchange factor SRM1
# 5hq2	nucleosome	yes bp
# 					5hyn	histone	Q15910#Histone-lysine N-methyltransferase EZH2
# 5hyn	histone	yes bp
# 					5i3l	histone	Q92784#Zinc finger protein DPF3
# 5i3l	histone	yes bp
# 					5iok	histone	P35189#Transcription initiation factor TFIID subunit 14
# 5iok	histone	yes bp
# 					5iql	histone	Q9ULM3#YEATS domain-containing protein 2
# 5iql	histone	yes bp
# 					5ix1	histone	F7BJB9#MORC family CW-type zinc finger protein 3
# 5ix1	histone	yes bp
# 					5ix2	histone	F7BJB9#MORC family CW-type zinc finger protein 3
# 5ix2	histone	yes bp
# 					5j3v	histone	Q92973#Transportin-1
# 5j3v	histone	yes bp
# 					5j9q	histone	P47128#Chromatin modification-related protein EAF6
# 5j9q	histone	yes bp
# 					5j9s	histone	Q03111#Protein ENL
# 5j9s	histone	yes bp
# 					5ja4	histone	P49736#DNA replication licensing factor MCM2
# 5ja4	histone	yes bp
# 					5jhn	histone	Q96KQ7#Histone-lysine N-methyltransferase EHMT2
# 5jhn	histone	yes bp
# 					5jin	histone	Q96KQ7#Histone-lysine N-methyltransferase EHMT2
# 5jin	histone	yes bp
# 					5jiy	histone	Q96KQ7#Histone-lysine N-methyltransferase EHMT2
# 5jiy	histone	yes bp
# 					5jj0	histone	Q96KQ7#Histone-lysine N-methyltransferase EHMT2
# 5jj0	histone	yes bp
# 					5jjy	histone	Q9BYW2#Histone-lysine N-methyltransferase SETD2
# 5jjy	histone	yes bp
# 					5jlb	histone	Q9BYW2#Histone-lysine N-methyltransferase SETD2
# 5jlb	histone	yes bp
# 5jrg	nucleosome	no bp
# 					5jxt	histone	G2QFM3#Chromatin-remodeling complex ATPase-like protein
# 5jxt	histone	yes bp
# 					5kdm	histone	Q9UER7#Death domain-associated protein 6
# 5kdm	histone	yes bp
# 					5kgf	nucleosome	P0CG47#Polyubiquitin-B
# 5kgf	nucleosome	yes bp
# 					5kjh	histone	G0RYC6, G0SDW4#null, null
# 5kjh	histone	yes bp
# 					5kkl	histone	G0S8H7#putative polycomb protein Eed
# 5kkl	histone	yes bp
# 					5kog	histone	P05205#Heterochromatin protein 1
# 5kog	histone	yes bp
# 					5m5g	histone	G0S8H7#putative polycomb protein EED
# 5m5g	histone	yes bp
# 					5mlu	nucleosome	P14349#Gag polyprotein
# 5mlu	nucleosome	yes bp
# 					5mr8	histone	Q9UPN9#E3 ubiquitin-protein ligase TRIM33
# 5mr8	histone	yes bp
# 5nl0	nucleosome	no bp
# 					5nnc	histone	O60885#Bromodomain-containing protein 4
# 5nnc	histone	yes bp
# 					5nnd	histone	O60885#Bromodomain-containing protein 4
# 5nnd	histone	yes bp
# 					5o9g	nucleosome	P32657#Chromo domain-containing protein 1
# 5o9g	nucleosome	yes bp
# 5omx	nucleosome	no bp
# 5ong	nucleosome	no bp
# 5onw	nucleosome	no bp
# 5oxv	nucleosome	no bp
# 					5oy3	histone	O15054#Lysine-specific demethylase 6B
# 5oy3	histone	yes bp
# 5oy7	nucleosome	no bp
# 					5svx	histone	Q14149#MORC family CW-type zinc finger protein 3
# 5svx	histone	yes bp
# 					5svy	histone	Q14149#MORC family CW-type zinc finger protein 3
# 5svy	histone	yes bp
# 					5szb	histone	Q92784#Zinc finger protein DPF3
# 5szb	histone	yes bp
# 					5szc	histone	Q92784#Zinc finger protein DPF3
# 5szc	histone	yes bp
# 					5t0k	histone	Q96KQ7#Histone-lysine N-methyltransferase EHMT2
# 5t0k	histone	yes bp
# 					5t0m	histone	Q96KQ7#Histone-lysine N-methyltransferase EHMT2
# 5t0m	histone	yes bp
# 					5t1g	histone	P83916#Chromobox protein homolog 1
# 5t1g	histone	yes bp
# 					5t1i	histone	Q13185#Chromobox protein homolog 3
# 5t1i	histone	yes bp
# 					5t8r	histone	Q9UIF9#Bromodomain adjacent to zinc finger domain protein 2A
# 5t8r	histone	yes bp
# 					5tbn	histone	Q9BVI0#PHD finger protein 20
# 5tbn	histone	yes bp
# 					5tdr	histone	P36124#SET domain-containing protein 3
# 5tdr	histone	yes bp
# 					5tdw	histone	P36124#SET domain-containing protein 3
# 5tdw	histone	yes bp
# 					5teg	histone	Q9NQR1#N-lysine methyltransferase KMT5A
# 5teg	histone	yes bp
# 					5u2j	histone	Q8WYB5#Histone acetyltransferase KAT6B
# 5u2j	histone	yes bp
# 					5v21	histone	Q9BYW2#Histone-lysine N-methyltransferase SETD2
# 5v21	histone	yes bp
# 					5v22	histone	Q9BYW2#Histone-lysine N-methyltransferase SETD2
# 5v22	histone	yes bp
# 					5va6	histone	B9RU15#Probable Histone-lysine N-methyltransferase ATXR5
# 5va6	histone	yes bp
# 					5vab	histone	I1N521#ATXR5 PHD domain
# 5vab	histone	yes bp
# 					5vac	histone	B9RU15#Probable Histone-lysine N-methyltransferase ATXR5
# 5vac	histone	yes bp
# 					5vah	histone	B9RU15#Probable Histone-lysine N-methyltransferase ATXR5
# 5vah	histone	yes bp
# 					5vbc	histone	B9RU15#Probable Histone-lysine N-methyltransferase ATXR5
# 5vbc	histone	yes bp
# 					5ve8	histone	Q6CMF0#Kap123
# 5ve8	histone	yes bp
# 					5vey	histone	Q8NCN4#E3 ubiquitin-protein ligase RNF169
# 5vey	histone	yes bp
# 					5vs7	histone	Q8IK82#Bromodomain protein, putative
# 5vs7	histone	yes bp
# 					5w0v	histone	Q6CMF0#Kap123
# 5w0v	histone	yes bp
# 					5wfc	histone	G0RYC6, G0SDW4#null, null
# 5wfc	histone	yes bp
# 					5wle	histone	Q9VG78#Protein partner of snf, isoform A
# 5wle	histone	yes bp
# 					5wvo	histone	P26358#DNA (cytosine-5)-methyltransferase 1
# 5wvo	histone	yes bp
# 					5wxg	histone	Q5VWG9#Transcription initiation factor TFIID subunit 3
# 5wxg	histone	yes bp
# 					5wxh	histone	Q5VWG9#Transcription initiation factor TFIID subunit 3
# 5wxh	histone	yes bp
# 					5x0x	nucleosome	P22082#Transcription regulatory protein SNF2
# 5x0x	nucleosome	yes bp
# 					5x0y	nucleosome	P22082#Transcription regulatory protein SNF2
# 5x0y	nucleosome	yes bp
# 					5x60	histone	O60341#Lysine-specific histone demethylase 1A
# 5x60	histone	yes bp
# 5x7x	nucleosome	no bp
# 					5xbk	histone	Q8TEX9#Importin-4
# 5xbk	histone	yes bp
# 5xf3	nucleosome	no bp
# 5xf4	nucleosome	no bp
# 5xf5	nucleosome	no bp
# 5xf6	nucleosome	no bp
# 					5xfq	histone	Q9Z1B8#PHD finger protein 1
# 5xfq	histone	yes bp
# 					5xfr	histone	Q9Y483#Metal-response element-binding transcription factor 2
# 5xfr	histone	yes bp
# 5xm0	nucleosome	no bp
# 5xm1	nucleosome	no bp
# 					5xnv	histone	Q9ULM3#YEATS domain-containing protein 2
# 5xnv	histone	yes bp
# 					5y20	histone	Q9FFF5#PHD finger protein ALFIN-LIKE 1
# 5y20	histone	yes bp
# 					5y5w	histone	Q9Y657#Spindlin-1
# 5y5w	histone	yes bp
# 					5yc4	histone	Q9M2B4#PHD finger protein ALFIN-LIKE 3
# 5yc4	histone	yes bp
# 					5yko	histone	Q8GUI6#Probable lysine-specific demethylase JMJ14
# 5yko	histone	yes bp
# 					5yvx	histone	Q2LAE1#Histone-lysine N-methyltransferase ASHH2
# 5yvx	histone	yes bp
# 					6asz	histone	P05205#Heterochromatin protein 1
# 6asz	histone	yes bp
# 					6at0	histone	P05205#Heterochromatin protein 1
# 6at0	histone	yes bp
# 					6axj	histone	P53930#Protein AF-9 homolog
# 6axj	histone	yes bp
# 					6bhd	histone	Q15047#Histone-lysine N-methyltransferase SETDB1
# 6bhd	histone	yes bp
# 					6bhe	histone	Q15047#Histone-lysine N-methyltransferase SETDB1
# 6bhe	histone	yes bp
# 					6bhg	histone	Q15047#Histone-lysine N-methyltransferase SETDB1
# 6bhg	histone	yes bp
# 					6bhh	histone	Q15047#Histone-lysine N-methyltransferase SETDB1
# 6bhh	histone	yes bp
# 					6bhi	histone	Q15047#Histone-lysine N-methyltransferase SETDB1
# 6bhi	histone	yes bp
# 					6biy	histone	P01903#HLA class II histocompatibility antigen, DR alpha chain
# 6biy	histone	yes bp
# 					6biz	histone	P01903#HLA class II histocompatibility antigen, DR alpha chain
# 6biz	histone	yes bp
# 					6buz	nucleosome	P0AEY0, Q96H22#P0AEY0:, Maltose-binding periplasmic protein, Q96H22:, Centromere protein N
# 6buz	nucleosome	yes bp
# 					6c0w	nucleosome	Q96H22#Centromere protein N
# 6c0w	nucleosome	yes bp
# 6esf	nucleosome	no bp
# 6esg	nucleosome	no bp
# 6esh	nucleosome	no bp
# 6esi	nucleosome	no bp
# 					6etx	nucleosome	Q9H9F9#Actin-related protein 5
# 6etx	nucleosome	yes bp
# 					6fml	nucleosome	G0S589#Actin related protein 5
# 6fml	nucleosome	yes bp
# 6fq5	nucleosome	no bp
# 6fq6	nucleosome	no bp
# 6fq8	nucleosome	no bp
# 6fy5	histone	no bp
