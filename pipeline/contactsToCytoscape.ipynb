# %%
#NOTES:
#To get a list of PDB that contains histones from 'text.csv':
#cut -f1 text.tsv | uniq | awk '{print tolower($0)}' | sort

#text.tsv should be sorted by pdb and then uniprot name
#it MUST have 'NA' in uniprot and name blanks

# %%
#!/usr/bin/env python 3
import re

PATH = "../data/Interfaces/"
#PATH = "/net/pan1/interactomes/pipeline/Interactome/Workflow/Interfaces/"
CHAIN_FILE = "text.tsv"
PDB_LIST = "pdbList.txt"

# %%
#PARAMETERS:
#fils is a string with path to the file to be checked

#RESULTS:
#Returns 1 or 0 depending on file existence 


def file_check(file):
    
    try:
        open(file, "r")
        return 1
    
    except IOError:
        print("Error: " + file + " does not appear to exist.")
        return 0

# %%
#PARAMETERS:
#name is a string with the name of chain
#typeCount is a 2-element list with the first one being an empty string and the second - 0 (iteger)

#RESULTS:
#Updates the typeCount array: the first element = general histone type(s); the second element = (should be) number of histones in chain

def is_histone(name, typeCount):

    if(not re.search(r'chaperone|ase|binding|p53 peptide|non-histone|jmjc|rna|synth', name, re.I)):
        if(re.search(r'histone.*h?\d|h?\d.*histone|h?\d.*histone-like|histone-like.*h?\d|histone macro.*h?\d|h?\d.*histone macro|h?\d.*\speptide|\speptide.*h?\d|h3k4me0|h3(1-9)k4me3|$h\d^|archaeal histone|histone peptide', name, re.I)):
            typeCount[1] = 1 #adds the number of histones in chain  (should be changed to actual number of histones in chain)

            if(re.search(r'h2a', name, re.I)):
                typeCount[0] += 'h2a#'
                
            elif(re.search(r'h2b', name, re.I)):
                typeCount[0] += 'h2b#'
                    
            elif(re.search(r'h3', name, re.I)):
                typeCount[0] += 'h3#'
                    
            elif(re.search(r'h4', name, re.I)):
                typeCount[0] += 'h4#'
                    
            elif(re.search(r'h1', name, re.I)):
                typeCount[0] += 'h1#'  
                    
            elif(re.search(r'h5', name, re.I)):
                typeCount[0] += 'h5#'
                    
            else:
                typeCount[0] += 'some histone'

# %%
#PARAMETERS: 
#pdbList is a text file with a header and one column PDB
#files is a list
#parameter is a string, either 'mapping' or 'interface' depending on desired results

#RESULTS:
#A list of absolute paths to either mapping files or interface files as it is stored on local NCBI machines


def get_files(pdbList, files, parameter):
    
    with open(pdbList, 'r') as pfh:
        pfh.readline()
        
        if(parameter == 'mapping'):
            
            for line in pfh:
                line = line.strip()
                folder = line[1] + line[2] 
                files.append(PATH + folder + '/' + line + '_chain_protein_mapping.tab')
                
        elif(parameter == 'interface'): 
            
            for line in pfh:
                line = line.strip()
                folder = line[1] + line[2]
                files.append(PATH + folder + '/' + line + '_atomic_contacts_5.0A.tab')

# %%
#PARAMETERS: 
#pdb is a string with pdb id
#parameter is a string, either 'mapping' or 'interface' depending on desired results

#RESULTS:
#An absolute paths to either mapping file or interface file as it is stored on local NCBI machines


def get_file(pdb, parameter):
    
    if(parameter == 'mapping'):
        folder = pdb[1] + pdb[2] 
        file = (PATH + folder + '/' + pdb + '_chain_protein_mapping.tab')
        return file  
        
    elif(parameter == 'interface'): 
        folder = pdb[1] + pdb[2]
        file = (PATH + folder + '/' + pdb + '_atomic_contacts_5.0A.tab')
        return file

# %%
#PARAMETERS:
#cFile is tab-separated file with a header and 4 columns: pdb, chain, uniprot, name
#dictionary is nested with the innermost dict being dictionary['pdb'] = {}

#RESULTS:
#The format of the end-product dictionary is: {pdb : {AlexChain: myChain#UNIPROT#name#type#nucleosome(bool)}}
#Example: {1alq : {'G': 'E#P02302#Histone H3.3C#H3#1'}}


def get_chain_dictionaries(cFile, dictionary): 
    
    with open(cFile, 'r') as cfh:
        cfh.readline()
        
        histoneCount = {} #is used to count number of histones in a structure!!!!!!!
        
        tempDict = {}
        tempDict['pdb'] = {}
            
        mappingFiles = [] 
        get_files(PDB_LIST, mappingFiles, 'mapping')
        
        
        
        
        for file in mappingFiles:
            try: #adds a pdb entry to the dict only if mapping file exists

                with open(file, 'r') as mfh:
                    mfh.readline() #skips header
                    pdb = file.split('/')[-1].split('_', 1)[0]

                    for mLine in mfh:
                        chainPair = mLine.split('\t', 2)
                        alexChain = chainPair[0]
                        myChain = chainPair[1]
                        
                        if(pdb in tempDict):
                            tempDict[pdb][alexChain] = myChain
                        else:
                            tempDict[pdb] = {alexChain : myChain}

            except IOError:
                pass
                #print("Error: " + mappingFile + " does not appear to exist.")
        
        
        
        
        for cLine in cfh:           
            fields = cLine.strip().split('\t')
            
            pdb = fields[0]
    
            if(pdb in tempDict): #continues only if a mapping file exists
                chain = fields[1]
                uniprot = fields[2]
                name = fields[3]


                histoneTypeAndCount = ['', 0]

                is_histone(name, histoneTypeAndCount) #checks whether the name looks like a histone!!!!!!!!!

                tempType = histoneTypeAndCount[0]
                tempCount = histoneTypeAndCount[1]

                if(pdb in histoneCount):
                    histoneCount[pdb] += tempCount #!!!!!!
                else:
                    histoneCount[pdb] = tempCount

                        
                        
                        
                try: #adds a chain entry to the dict only if there exists a corresponding chain in the mapping file
                    alexChain = list(tempDict[pdb].keys())[list(tempDict[pdb].values()).index(chain)]

                    if(pdb in dictionary):

                        if(tempCount): #checks if chain is a histone!!!!
                            dictionary[pdb][alexChain] = str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + tempType #!!!!

                        else: #!!!!
                            dictionary[pdb][alexChain] = str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + 'other#' #!!!!

                    else:

                        if(tempCount): #checks if chain is a histone!!!!
                            dictionary[pdb] = {alexChain : str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + tempType} #!!!!

                        else: #!!!!
                            dictionary[pdb] = {alexChain : str(tempDict[pdb][alexChain]) + '#' + uniprot + '#' + name + '#' + 'other#'} #!!!!
                        
                except ValueError:
                    #print("Error: " + ValueError + ", in " + pdb)               
                    pass

                    
                    
                    
        for structure in histoneCount:

            if(histoneCount[structure] > 3): #checks if pdb has at least a half of nucleosome!!!!!!!

                for chain in dictionary[structure]: #!!!!!!
                    dictionary[structure][chain] = dictionary[structure][chain] + '1' #!!!!!!

            else: #!!!!!!

                for chain in dictionary[structure]: #!!!!!
                    dictionary[structure][chain] = dictionary[structure][chain] + '0' #!!!!!!

# %%
#PARAMETERS:
#interfaceFiles is a list of strings containing names of interface files
#chainDictionary is a dictionary produced by 'get_chain_dictionaries'
#interfaceDictonary is a nested dictionary with the innermost dict being interfaceDictionary['uniprotPair'] = {}, where the values are lists of the next form [chain pair data, residue number, pdb IDs] 
#Example: 'P84233@P62799': {'44': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla$q5cl']
#note that data fields of a chain is separated by #, @ separates chains binding partner chains, $ separates chain pairs and pdb structures


def residue_frequency(interfaceFiles, chainDictionary, interfaceDictionary):
    for file in interfaceFiles:
        pdb = file.split('/')[-1].split('_', 1)[0] 
        
        try:
            with open (file, 'r') as ifh:
                ifh.readline() #skips header

                for line in ifh:
                    lineFields = line.split('\t', 6) #gets only the first 8 columns !!!

                    chain1 = lineFields[0].split('_', 1)[0] # the split part treats biological assembly chains as separate chains ???
                    chain2 = lineFields[4].split('_', 1)[0]

                    residue1 = lineFields[2]
                    residue2 = lineFields[5]

                    uniprot1 = chainDictionary[pdb][chain1].split('#', 2)[1]
                    uniprot2 = chainDictionary[pdb][chain2].split('#', 2)[1]

                    uniprotPair1 = uniprot1 + '@' + uniprot2
                    uniprotPair2 = uniprot2 + '@' + uniprot1

                    chainPair1 = chainDictionary[pdb][chain1] + '@' + chainDictionary[pdb][chain2]
                    chainPair2 = chainDictionary[pdb][chain2] + '@' + chainDictionary[pdb][chain1]

                    if(uniprotPair1 in interfaceDictionary):

                        if(residue1 in interfaceDictionary[uniprotPair1]):
                            interfaceDictionary[uniprotPair1][residue1][1] += 1  

                            if(chainPair1 not in interfaceDictionary[uniprotPair1][residue1][0]):
                                interfaceDictionary[uniprotPair1][residue1][0] += '$' + chainPair1                       
                                
                                if(pdb not in interfaceDictionary[uniprotPair1][residue1][2]):
                                    interfaceDictionary[uniprotPair1][residue1][2] += '$' + pdb
                                    
                        else:
                            interfaceDictionary[uniprotPair1][residue1] = [chainPair1, 1, pdb]    #format of the innermost dict        

                    elif(uniprotPair2 in interfaceDictionary):

                        if(residue2 in interfaceDictionary[uniprotPair2]):
                            interfaceDictionary[uniprotPair2][residue2][1] += 1

                            if(chainPair2 not in interfaceDictionary[uniprotPair2][residue2][0]):
                                interfaceDictionary[uniprotPair2][residue2][0] += '$' + chainPair2                        

                                if(pdb not in interfaceDictionary[uniprotPair2][residue2][2]):
                                    interfaceDictionary[uniprotPair2][residue2][2] += '$' + pdb
                                    
                        else:
                            interfaceDictionary[uniprotPair2][residue2] = [chainPair2, 1, pdb]

                    else:
                         interfaceDictionary[uniprotPair1] = {residue1 : [chainPair1, 1, pdb]}  
                            
        except IOError:
            #print("Error: " + interfaceFile + " does not appear to exist.")
            pass

# %%
def main():
    chainDictionary = {}
    chainDictionary['chain'] = {}
    
    get_chain_dictionaries(CHAIN_FILE, chainDictionary)
    
    interfaceFiles = []
    get_files(PDB_LIST, interfaceFiles, 'interface')
    
    interfaceDictionary = {}
    interfaceDictionary['uniprotPair'] = {}
    
    residue_frequency(interfaceFiles, chainDictionary, interfaceDictionary)
    
    for pair in interfaceDictionary:
        print(pair + ': ' + str(interfaceDictionary[pair]))
        print('\n')
    print(interfaceDictionary)

# %%
if __name__ == "__main__":
    main()
# Out:
# uniprotPair: {}
#
#
# P84233@P62799: {'44': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla'], '47': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 52, '1zla'], '48': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla'], '50': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 60, '1zla'], '51': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 122, '1zla'], '54': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 129, '1zla'], '55': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 54, '1zla'], '57': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 29, '1zla'], '58': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 24, '1zla'], '59': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 37, '1zla'], '60': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 6, '1zla'], '61': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 147, '1zla'], '62': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 37, '1zla'], '63': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 5, '1zla'], '66': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla'], '67': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 25, '1zla'], '69': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 51, '1zla'], '70': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 80, '1zla'], '71': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 18, '1zla'], '73': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 98, '1zla'], '74': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 55, '1zla'], '75': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 16, '1zla'], '78': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 100, '1zla'], '79': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 40, '1zla'], '81': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 25, '1zla'], '82': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 47, '1zla'], '83': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 113, '1zla'], '84': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 70, '1zla'], '85': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 86, '1zla'], '87': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 40, '1zla'], '88': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 54, '1zla'], '90': ['A#P84233#Histone H3.2#h3#1@B#P62799# ...
#
#
# P84233@P06897: {'131': ['A#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1$E#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 2, '1zla'], '42': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 2, '1zla'], '48': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 15, '1zla'], '51': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 6, '1zla'], '52': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 7, '1zla'], '54': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 1, '1zla'], '55': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 71, '1zla'], '56': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 12, '1zla'], '57': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 4, '1zla'], '58': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 42, '1zla'], '59': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 7, '1zla'], '60': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 4, '1zla'], '94': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 37, '1zla'], '98': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 3, '1zla'], '101': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 1, '1zla'], '105': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 2, '1zla'], '108': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 5, '1zla'], '109': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 3, '1zla'], '112': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 11, '1zla'], '117': ['A#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 5, '1zla'], 'T': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 62, '1zla'], 'K': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 9, '1zla'], 'Q': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 68, '1zla'], 'S': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 7, '1zla'], 'A': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 4, '1zla'], 'E': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 40, '1zla'], 'L': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 23, '1zla'], 'V': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 7, '1zla'], 'I': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 14, '1zla'], 'R': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 6, '1zla'], 'N': ['E#P84233#Histone H3.2#h3#1@C#P06897#Histone H2A type 1#h2a#1', 6, '1zla'], '129': ['E#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 3, '1zla'], '132': ['E#P84233#Histone H3.2#h3#1@G#P06897#Histone H2A type 1#h2a#1', 2, '1zla']}
#
#
# P84233@P84233: {'106': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 18, '1zla'], '109': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 25, '1zla'], '110': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 23, '1zla'], '111': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 2, '1zla'], '113': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 71, '1zla'], '114': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 19, '1zla'], '116': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 5, '1zla'], '122': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 11, '1zla'], '123': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 11, '1zla'], '126': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 29, '1zla'], '127': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 6, '1zla'], '129': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 16, '1zla'], '130': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 53, '1zla'], '131': ['A#P84233#Histone H3.2#h3#1@E#P84233#Histone H3.2#h3#1', 8, '1zla']}
#
#
# P62799@P06897: {'64': ['B#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 1, '1zla'], '40': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 9, '1zla'], '42': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 3, '1zla'], '44': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 23, '1zla'], '94': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 4, '1zla'], '95': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 6, '1zla'], '96': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 45, '1zla'], '97': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 27, '1zla'], '98': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 65, '1zla'], '99': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 2, '1zla'], '100': ['B#P62799#Histone H4#h4#1@G#P06897#Histone H2A type 1#h2a#1', 4, '1zla'], 'Y': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 54, '1zla'], 'T': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 41, '1zla'], 'G': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 11, '1zla'], 'R': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 19, '1zla'], 'L': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 24, '1zla'], 'F': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 4, '1zla'], 'K': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 24, '1zla'], 'V': ['F#P62799#Histone H4#h4#1@C#P06897#Histone H2A type 1#h2a#1', 1, '1zla']}
#
#
# P62799@P02281: {'68': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 24, '1zla'], '71': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 30, '1zla'], '72': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 69, '1zla'], '74': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 6, '1zla'], '75': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 216, '1zla'], '76': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 19, '1zla'], '77': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 23, '1zla'], '88': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 118, '1zla'], '91': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 7, '1zla'], '92': ['B#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1$F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 96, '1zla'], '96': ['B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 2, '1zla'], '97': ['B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 2, '1zla'], '98': ['B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 98, '1zla'], '99': ['B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 24, '1zla'], '100': ['B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 3, '1zla'], '101': ['B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 5, '1zla'], '102': ['B#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 34, '1zla'], 'G': ['F#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1', 50, '1zla'], 'F': ['F#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1', 3, '1zla'], 'Y': ['F#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1', 90, '1zla'], 'L': ['F#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1', 2, '1zla'], 'T': ['F#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1', 3, '1zla'], 'K': ['F#P62799#Histone H4#h4#1@D#P02281#Histone H2B 1.1#h2b#1', 5, '1zla'], '78': ['F#P62799#Histone H4#h4#1@H#P02281#Histone H2B 1.1#h2b#1', 1, '1zla']}
#
#
# P06897@P02281: {'17': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 42, '1zla'], '19': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1', 5, '1zla'], '20': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 115, '1zla'], '21': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 88, '1zla'], '22': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 9, '1zla'], '23': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 7, '1zla'], '24': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 69, '1zla'], '25': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 90, '1zla'], '26': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 70, '1zla'], '29': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 97, '1zla'], '30': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 21, '1zla'], '32': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 25, '1zla'], '33': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 32, '1zla'], '34': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 26, '1zla'], '38': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$C#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 10, '1zla'], '39': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 144, '1zla'], '40': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 41, '1zla'], '41': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 39, '1zla'], '42': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 122, '1zla'], '43': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 30, '1zla'], '44': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 25, '1zla'], '45': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 13, '1zla'], '46': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 33, '1zla'], '47': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 67, '1zla'], '49': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 69, '1zla'], '50': ['C#P06897#Histone H2A type 1#h2a#1@D#P02281#Histone H2B 1.1#h2b#1$G#P06897#Histone H2A type 1#h2a#1@H#P02281#Histone H2B 1.1#h2b#1', 269, '1zla'], '51': ...
#
#
# P06897@P06897: {'35': ['C#P06897#Histone H2A type 1#h2a#1@G#P06897#Histone H2A type 1#h2a#1', 1, '1zla'], '38': ['C#P06897#Histone H2A type 1#h2a#1@G#P06897#Histone H2A type 1#h2a#1', 50, '1zla'], '39': ['C#P06897#Histone H2A type 1#h2a#1@G#P06897#Histone H2A type 1#h2a#1', 8, '1zla'], '40': ['C#P06897#Histone H2A type 1#h2a#1@G#P06897#Histone H2A type 1#h2a#1', 14, '1zla'], '41': ['C#P06897#Histone H2A type 1#h2a#1@G#P06897#Histone H2A type 1#h2a#1', 16, '1zla']}
#
#
# P06897@Q9DUM3: {'23': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 1, '1zla'], '24': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 3, '1zla'], '53': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 5, '1zla'], '56': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 12, '1zla'], '57': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 37, '1zla'], '60': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 9, '1zla'], '61': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 58, '1zla'], '64': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 32, '1zla'], '65': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 2, '1zla'], '68': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 1, '1zla'], '90': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 11, '1zla'], '92': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 12, '1zla'], '93': ['G#P06897#Histone H2A type 1#h2a#1@K#Q9DUM3#NA#other#1', 6, '1zla']}
#
#
# P02281@Q9DUM3: {'44': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 2, '1zla'], '47': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 46, '1zla'], '48': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 19, '1zla'], '49': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 5, '1zla'], '105': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 10, '1zla'], '106': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 23, '1zla'], '109': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 43, '1zla'], '113': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 44, '1zla'], '116': ['H#P02281#Histone H2B 1.1#h2b#1@K#Q9DUM3#NA#other#1', 9, '1zla']}
#
#
# {'uniprotPair': {}, 'P84233@P62799': {'44': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla'], '47': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 52, '1zla'], '48': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla'], '50': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 60, '1zla'], '51': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 122, '1zla'], '54': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 129, '1zla'], '55': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 54, '1zla'], '57': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 29, '1zla'], '58': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 24, '1zla'], '59': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 37, '1zla'], '60': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 6, '1zla'], '61': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 147, '1zla'], '62': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 37, '1zla'], '63': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 5, '1zla'], '66': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 17, '1zla'], '67': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 25, '1zla'], '69': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 51, '1zla'], '70': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 80, '1zla'], '71': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 18, '1zla'], '73': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 98, '1zla'], '74': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 55, '1zla'], '75': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 16, '1zla'], '78': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 100, '1zla'], '79': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 40, '1zla'], '81': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 25, '1zla'], '82': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 47, '1zla'], '83': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 113, '1zla'], '84': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 70, '1zla'], '85': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 86, '1zla'], '87': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 40, '1zla'], '88': ['A#P84233#Histone H3.2#h3#1@B#P62799#Histone H4#h4#1$E#P84233#Histone H3.2#h3#1@F#P62799#Histone H4#h4#1', 54, '1zla'], '90': ['A#P84233#Histo ...
